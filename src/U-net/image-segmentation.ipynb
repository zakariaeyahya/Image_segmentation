# %%
# !nvidia-smi
# Out:
# Fri Jan 10 08:59:52 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0             26W /  250W |       0MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# Au début du code, après les imports, ajoutez :
import tensorflow as tf

# Vérifier si le GPU est disponible
print("GPU disponible:", tf.test.is_built_with_cuda())
print("Périphériques disponibles:", tf.config.list_physical_devices())

# Configuration pour utiliser le GPU
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU configuré avec succès")
    except RuntimeError as e:
        print(e)
# Out:
# GPU disponible: True
# Périphériques disponibles: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU configuré avec succès

# %%
import os

def afficher_dossiers(chemin, niveau=0):
    """
    Affiche uniquement la structure des dossiers à partir du chemin spécifié.
    
    Args:
        chemin (str): Le chemin du dossier à explorer
        niveau (int): Le niveau d'indentation actuel
    """
    try:
        elements = os.listdir(chemin)
    except:
        print("⚠️ Erreur d'accès au dossier:", chemin)
        return

    # Filtrer pour ne garder que les dossiers et les trier
    dossiers = sorted([elem for elem in elements 
                      if os.path.isdir(os.path.join(chemin, elem))])

    for dossier in dossiers:
        chemin_complet = os.path.join(chemin, dossier)
        indentation = "│   " * niveau
        print(f"{indentation}📁 {dossier}/")
        # Appel récursif pour le sous-dossier
        afficher_dossiers(chemin_complet, niveau + 1)

# Utilisation avec votre chemin de base
base_path = '/kaggle/input/cityscape-data/data'
print(f"Structure des dossiers : {base_path}")
print("=" * 50)
afficher_dossiers(base_path)
# Out:
# Structure des dossiers : /kaggle/input/cityscape-data/data
# ==================================================
# 📁 test/
# │   📁 images/
# │   📁 masks/
# 📁 train/
# │   📁 images/
# │   📁 masks/
# 📁 val/
# │   📁 images/
# │   📁 masks/

# %%
import glob
# Configuration des chemins
base_path = '/kaggle/input/cityscape-data/data'
images_path = os.path.join(base_path)
masks_path = os.path.join(base_path)

# Lecture des datasets
# Training
train_img = glob.glob(os.path.join(images_path, 'train', 'images', '*.png'))
train_label = []
for img_path in train_img:
    img_name = os.path.basename(img_path)
    label_path = os.path.join(masks_path, 'train', 'masks', img_name)
    train_label.append(label_path)

# Validation
val_img = glob.glob(os.path.join(images_path, 'val', 'images', '*.png'))
val_label = []
for img_path in val_img:
    img_name = os.path.basename(img_path)
    label_path = os.path.join(masks_path, 'val', 'masks', img_name)
    val_label.append(label_path)

# Test
test_img = glob.glob(os.path.join(images_path, 'test', 'images', '*.png'))
test_label = []
for img_path in test_img:
    img_name = os.path.basename(img_path)
    label_path = os.path.join(masks_path, 'test', 'masks', img_name)
    test_label.append(label_path)

print(f"Nombre d'images d'entraînement : {len(train_img)}")
print(f"Nombre d'images de validation : {len(val_img)}")
print(f"Nombre d'images de test : {len(test_img)}")
# Out:
# Nombre d'images d'entraînement : 2975
# Nombre d'images de validation : 500
# Nombre d'images de test : 1525

# %%
import os
import glob
import numpy as np
import shutil
from sklearn.model_selection import train_test_split

# Configuration des chemins
input_path = '/kaggle/input/cityscape-data/data'
working_path = '/kaggle/working/data'  # Nouveau dossier de travail

# Créer la structure des dossiers dans working
for folder in ['train', 'val']:
    for subfolder in ['images', 'masks']:
        os.makedirs(os.path.join(working_path, folder, subfolder), exist_ok=True)

# Copier d'abord tous les fichiers de train et val
for folder in ['train', 'val']:
    for subfolder in ['images', 'masks']:
        src_files = glob.glob(os.path.join(input_path, folder, subfolder, '*.png'))
        for file in src_files:
            filename = os.path.basename(file)
            dest = os.path.join(working_path, folder, subfolder, filename)
            shutil.copy2(file, dest)

# Maintenant traiter les fichiers de test
test_images = glob.glob(os.path.join(input_path, 'test', 'images', '*.png'))
test_masks = glob.glob(os.path.join(input_path, 'test', 'masks', '*.png'))

# Split des données test
test_train_img, test_val_img, test_train_mask, test_val_mask = train_test_split(
    test_images, test_masks, test_size=0.2, random_state=42
)

# Fonction pour copier les fichiers
def copy_files(files, destination_folder):
    for file in files:
        filename = os.path.basename(file)
        destination = os.path.join(working_path, destination_folder, 'images' if 'images' in file else 'masks', filename)
        shutil.copy2(file, destination)
        print(f"Copié: {filename} vers {destination_folder}")

# Copier les fichiers
copy_files(test_train_img, 'train')
copy_files(test_train_mask, 'train')

copy_files(test_val_img, 'val')
copy_files(test_val_mask, 'val')

# Vérifier les nombres de fichiers après transfert
train_images = len(glob.glob(os.path.join(working_path, 'train', 'images', '*.png')))
train_masks = len(glob.glob(os.path.join(working_path, 'train', 'masks', '*.png')))
val_images = len(glob.glob(os.path.join(working_path, 'val', 'images', '*.png')))
val_masks = len(glob.glob(os.path.join(working_path, 'val', 'masks', '*.png')))

print(f"\nNombre final d'images dans train: {train_images}")
print(f"Nombre final de masques dans train: {train_masks}")
print(f"Nombre final d'images dans val: {val_images}")
print(f"Nombre final de masques dans val: {val_masks}")

# Mettre à jour les chemins pour la suite de votre code
base_path = working_path  # Utiliser le nouveau chemin pour la suite
# Out:
# Copié: image4912.png vers train
# Copié: image4008.png vers train
# Copié: image4337.png vers train
# Copié: image4280.png vers train
# Copié: image4164.png vers train
# Copié: image4764.png vers train
# Copié: image4441.png vers train
# Copié: image4754.png vers train
# Copié: image4649.png vers train
# Copié: image4295.png vers train
# Copié: image3606.png vers train
# Copié: image4022.png vers train
# Copié: image3633.png vers train
# Copié: image4652.png vers train
# Copié: image4400.png vers train
# Copié: image4434.png vers train
# Copié: image4339.png vers train
# Copié: image3930.png vers train
# Copié: image4147.png vers train
# Copié: image4903.png vers train
# Copié: image4755.png vers train
# Copié: image4388.png vers train
# Copié: image3501.png vers train
# Copié: image4991.png vers train
# Copié: image4733.png vers train
# Copié: image3560.png vers train
# Copié: image4890.png vers train
# Copié: image3662.png vers train
# Copié: image3760.png vers train
# Copié: image4112.png vers train
# Copié: image4382.png vers train
# Copié: image3985.png vers train
# Copié: image4067.png vers train
# Copié: image3827.png vers train
# Copié: image3796.png vers train
# Copié: image4229.png vers train
# Copié: image4007.png vers train
# Copié: image4706.png vers train
# Copié: image3653.png vers train
# Copié: image3565.png vers train
# Copié: image4614.png vers train
# Copié: image4547.png vers train
# Copié: image3799.png vers train
# Copié: image3803.png vers train
# Copié: image4358.png vers train
# Copié: image3693.png vers train
# Copié: image4059.png vers train
# Copié: image4041.png vers train
# Copié: image3866.png vers train
# Copié: image4804.png vers train
# Copié: image4891.png vers train
# Copié: image3872.png vers train
# Copié: image4336.png vers train
# Copié: image4730.png vers train
# Copié: image4759.png vers train
# Copié: image4392.png vers train
# Copié: image4727.png vers train
# Copié: image4932.png vers train
# Copié: image4925.png vers train
# Copié: image4313.png vers train
# Copié: image3823.png vers train
# Copié: image3608.png vers train
# Copié: image4432.png vers train
# Copié: image4317.png vers train
# Copié: image4276.png vers train
# Copié: image4927.png vers train
# Copié: image3999.png vers train
# Copié: image3790.png vers train
# Copié: image3889.png vers train
# Copié: image3685.png vers train
# Copié: image3652.png vers train
# Copié: image3940.png vers train
# Copié: image4536.png vers train
# Copié: image4898.png vers train
# Copié: image4082.png vers train
# Copié: image3537.png vers train
# Copié: image4464.png vers train
# Copié: image3739.png vers train
# Copié: image3563.png vers train
# Copié: image3791.png vers train
# Copié: image3593.png vers train
# Copié: image4483.png vers train
# Copié: image4783.png vers train
# Copié: image4471.png vers train
# Copié: image3728.png vers train
# Copié: image3599.png vers train
# Copié: image4763.png vers train
# Copié: image4390.png vers train
# Copié: image4844.png vers train
# Copié: image4198.png vers train
# Copié: image4366.png vers train
# Copié: image4163.png vers train
# Copié: image3556.png vers train
# Copié: image4004.png vers train
# Copié: image4042.png vers train
# Copié: image4508.png vers train
# Copié: image4153.png vers train
# Copié: image3536.png vers train
# Copié: image3901.png vers train
# Copié: image4962.png vers train
# Copié: image4676.png vers train
# Copié: image3643.png vers train
# Copié: image4663.png vers train
# Copié: image4994.png vers train
# Copié: image4105.png vers train
# Copié: image3616.png vers train
# Copié: image4093.png vers train
# Copié: image4767.png vers train
# Copié: image3609.png vers train
# Copié: image4506.png vers train
# Copié: image4271.png vers train
# Copié: image3543.png vers train
# Copié: image3890.png vers train
# Copié: image4525.png vers train
# Copié: image4487.png vers train
# Copié: image4132.png vers train
# Copié: image3585.png vers train
# Copié: image4344.png vers train
# Copié: image4141.png vers train
# Copié: image4963.png vers train
# Copié: image4373.png vers train
# Copié: image4260.png vers train
# Copié: image4262.png vers train
# Copié: image4559.png vers train
# Copié: image3745.png vers train
# Copié: image4941.png vers train
# Copié: image3925.png vers train
# Copié: image4650.png vers train
# Copié: image4762.png vers train
# Copié: image4967.png vers train
# Copié: image4452.png vers train
# Copié: image4866.png vers train
# Copié: image4886.png vers train
# Copié: image3611.png vers train
# Copié: image4422.png vers train
# Copié: image4519.png vers train
# Copié: image4729.png vers train
# Copié: image3719.png vers train
# Copié: image3932.png vers train
# Copié: image3758.png vers train
# Copié: image4114.png vers train
# Copié: image3905.png vers train
# Copié: image4909.png vers train
# Copié: image4195.png vers train
# Copié: image3906.png vers train
# Copié: image4723.png vers train
# Copié: image4818.png vers train
# Copié: image4491.png vers train
# Copié: image4010.png vers train
# Copié: image4306.png vers train
# Copié: image4961.png vers train
# Copié: image4024.png vers train
# Copié: image4813.png vers train
# Copié: image3968.png vers train
# Copié: image4488.png vers train
# Copié: image4406.png vers train
# Copié: image3737.png vers train
# Copié: image3786.png vers train
# Copié: image3597.png vers train
# Copié: image4140.png vers train
# Copié: image4812.png vers train
# Copié: image4739.png vers train
# Copié: image4299.png vers train
# Copié: image4884.png vers train
# Copié: image4554.png vers train
# Copié: image4896.png vers train
# Copié: image3772.png vers train
# Copié: image3971.png vers train
# Copié: image4627.png vers train
# Copié: image4809.png vers train
# Copié: image3715.png vers train
# Copié: image4769.png vers train
# Copié: image4596.png vers train
# Copié: image4033.png vers train
# Copié: image3754.png vers train
# Copié: image4342.png vers train
# Copié: image4666.png vers train
# Copié: image3610.png vers train
# Copié: image3628.png vers train
# Copié: image3876.png vers train
# Copié: image3945.png vers train
# Copié: image3776.png vers train
# Copié: image4534.png vers train
# Copié: image4667.png vers train
# Copié: image4028.png vers train
# Copié: image3479.png vers train
# Copié: image3813.png vers train
# Copié: image4745.png vers train
# Copié: image4824.png vers train
# Copié: image3583.png vers train
# Copié: image4775.png vers train
# Copié: image4719.png vers train
# Copié: image4625.png vers train
# Copié: image3575.png vers train
# Copié: image4881.png vers train
# Copié: image4928.png vers train
# Copié: image4323.png vers train
# Copié: image4794.png vers train
# Copié: image4136.png vers train
# Copié: image3826.png vers train
# Copié: image3919.png vers train
# Copié: image4194.png vers train
# Copié: image3883.png vers train
# Copié: image4237.png vers train
# Copié: image4521.png vers train
# Copié: image3476.png vers train
# Copié: image4788.png vers train
# Copié: image3668.png vers train
# Copié: image4146.png vers train
# Copié: image4689.png vers train
# Copié: image3692.png vers train
# Copié: image4533.png vers train
# Copié: image4394.png vers train
# Copié: image4207.png vers train
# Copié: image4990.png vers train
# Copié: image4083.png vers train
# Copié: image3725.png vers train
# Copié: image4876.png vers train
# Copié: image4562.png vers train
# Copié: image4117.png vers train
# Copié: image4106.png vers train
# Copié: image3571.png vers train
# Copié: image4917.png vers train
# Copié: image3783.png vers train
# Copié: image3847.png vers train
# Copié: image4535.png vers train
# Copié: image4611.png vers train
# Copié: image4298.png vers train
# Copié: image4664.png vers train
# Copié: image4381.png vers train
# Copié: image3671.png vers train
# Copié: image3857.png vers train
# Copié: image4230.png vers train
# Copié: image3871.png vers train
# Copié: image4096.png vers train
# Copié: image4065.png vers train
# Copié: image4138.png vers train
# Copié: image4074.png vers train
# Copié: image3731.png vers train
# Copié: image4225.png vers train
# Copié: image4500.png vers train
# Copié: image3480.png vers train
# Copié: image3869.png vers train
# Copié: image3632.png vers train
# Copié: image4180.png vers train
# Copié: image4016.png vers train
# Copié: image3544.png vers train
# Copié: image4185.png vers train
# Copié: image4918.png vers train
# Copié: image4193.png vers train
# Copié: image3519.png vers train
# Copié: image4006.png vers train
# Copié: image4268.png vers train
# Copié: image4092.png vers train
# Copié: image4900.png vers train
# Copié: image3562.png vers train
# Copié: image4550.png vers train
# Copié: image4698.png vers train
# Copié: image4139.png vers train
# Copié: image4707.png vers train
# Copié: image4470.png vers train
# Copié: image4393.png vers train
# Copié: image3804.png vers train
# Copié: image3534.png vers train
# Copié: image4184.png vers train
# Copié: image3839.png vers train
# Copié: image4183.png vers train
# Copié: image3740.png vers train
# Copié: image3640.png vers train
# Copié: image4495.png vers train
# Copié: image4569.png vers train
# Copié: image3726.png vers train
# Copié: image4802.png vers train
# Copié: image4948.png vers train
# Copié: image3550.png vers train
# Copié: image3949.png vers train
# Copié: image4553.png vers train
# Copié: image4879.png vers train
# Copié: image3636.png vers train
# Copié: image4009.png vers train
# Copié: image4404.png vers train
# Copié: image3842.png vers train
# Copié: image3603.png vers train
# Copié: image3781.png vers train
# Copié: image4541.png vers train
# Copié: image4856.png vers train
# Copié: image4674.png vers train
# Copié: image3884.png vers train
# Copié: image4792.png vers train
# Copié: image4482.png vers train
# Copié: image4835.png vers train
# Copié: image3881.png vers train
# Copié: image4037.png vers train
# Copié: image4600.png vers train
# Copié: image3840.png vers train
# Copié: image4005.png vers train
# Copié: image3661.png vers train
# Copié: image4959.png vers train
# Copié: image4747.png vers train
# Copié: image4015.png vers train
# Copié: image4803.png vers train
# Copié: image4626.png vers train
# Copié: image4655.png vers train
# Copié: image3527.png vers train
# Copié: image3806.png vers train
# Copié: image4513.png vers train
# Copié: image4356.png vers train
# Copié: image4218.png vers train
# Copié: image4950.png vers train
# Copié: image3549.png vers train
# Copié: image3657.png vers train
# Copié: image4760.png vers train
# Copié: image3937.png vers train
# Copié: image4993.png vers train
# Copié: image4836.png vers train
# Copié: image4851.png vers train
# Copié: image3539.png vers train
# Copié: image4572.png vers train
# Copié: image4737.png vers train
# Copié: image3963.png vers train
# Copié: image4774.png vers train
# Copié: image4591.png vers train
# Copié: image4150.png vers train
# Copié: image3777.png vers train
# Copié: image3995.png vers train
# Copié: image4869.png vers train
# Copié: image4750.png vers train
# Copié: image4718.png vers train
# Copié: image3540.png vers train
# Copié: image4251.png vers train
# Copié: image3979.png vers train
# Copié: image4169.png vers train
# Copié: image4238.png vers train
# Copié: image4862.png vers train
# Copié: image4867.png vers train
# Copié: image4357.png vers train
# Copié: image4845.png vers train
# Copié: image4811.png vers train
# Copié: image4484.png vers train
# Copié: image3667.png vers train
# Copié: image3655.png vers train
# Copié: image4678.png vers train
# Copié: image4052.png vers train
# Copié: image4612.png vers train
# Copié: image4057.png vers train
# Copié: image4598.png vers train
# Copié: image3984.png vers train
# Copié: image4328.png vers train
# Copié: image3801.png vers train
# Copié: image3874.png vers train
# Copié: image4573.png vers train
# Copié: image4126.png vers train
# Copié: image4436.png vers train
# Copié: image4064.png vers train
# Copié: image3907.png vers train
# Copié: image3950.png vers train
# Copié: image4494.png vers train
# Copié: image4200.png vers train
# Copié: image4923.png vers train
# Copié: image4489.png vers train
# Copié: image4907.png vers train
# Copié: image4846.png vers train
# Copié: image3989.png vers train
# Copié: image4473.png vers train
# Copié: image4934.png vers train
# Copié: image3674.png vers train
# Copié: image4620.png vers train
# Copié: image4324.png vers train
# Copié: image4957.png vers train
# Copié: image4124.png vers train
# Copié: image4602.png vers train
# Copié: image4246.png vers train
# Copié: image4335.png vers train
# Copié: image4687.png vers train
# Copié: image4327.png vers train
# Copié: image3649.png vers train
# Copié: image4691.png vers train
# Copié: image4421.png vers train
# Copié: image3851.png vers train
# Copié: image4267.png vers train
# Copié: image3627.png vers train
# Copié: image4622.png vers train
# Copié: image4223.png vers train
# Copié: image3573.png vers train
# Copié: image4325.png vers train
# Copié: image4058.png vers train
# Copié: image4636.png vers train
# Copié: image4409.png vers train
# Copié: image4711.png vers train
# Copié: image4365.png vers train
# Copié: image4133.png vers train
# Copié: image4657.png vers train
# Copié: image4253.png vers train
# Copié: image3955.png vers train
# Copié: image4428.png vers train
# Copié: image4277.png vers train
# Copié: image4209.png vers train
# Copié: image3734.png vers train
# Copié: image3891.png vers train
# Copié: image4854.png vers train
# Copié: image3613.png vers train
# Copié: image4808.png vers train
# Copié: image4906.png vers train
# Copié: image3896.png vers train
# Copié: image4868.png vers train
# Copié: image3988.png vers train
# Copié: image3921.png vers train
# Copié: image3829.png vers train
# Copié: image4693.png vers train
# Copié: image4849.png vers train
# Copié: image3952.png vers train
# Copié: image3817.png vers train
# Copié: image4063.png vers train
# Copié: image4883.png vers train
# Copié: image4784.png vers train
# Copié: image4740.png vers train
# Copié: image3924.png vers train
# Copié: image4212.png vers train
# Copié: image4776.png vers train
# Copié: image3798.png vers train
# Copié: image4346.png vers train
# Copié: image3800.png vers train
# Copié: image3983.png vers train
# Copié: image3584.png vers train
# Copié: image4023.png vers train
# Copié: image4128.png vers train
# Copié: image4616.png vers train
# Copié: image4086.png vers train
# Copié: image3675.png vers train
# Copié: image4314.png vers train
# Copié: image3991.png vers train
# Copié: image4606.png vers train
# Copié: image3576.png vers train
# Copié: image3834.png vers train
# Copié: image4992.png vers train
# Copié: image4949.png vers train
# Copié: image3895.png vers train
# Copié: image3848.png vers train
# Copié: image3978.png vers train
# Copié: image4639.png vers train
# Copié: image4669.png vers train
# Copié: image4839.png vers train
# Copié: image4933.png vers train
# Copié: image4966.png vers train
# Copié: image3580.png vers train
# Copié: image4321.png vers train
# Copié: image4215.png vers train
# Copié: image4201.png vers train
# Copié: image4675.png vers train
# Copié: image3645.png vers train
# Copié: image3878.png vers train
# Copié: image3771.png vers train
# Copié: image4671.png vers train
# Copié: image4942.png vers train
# Copié: image4599.png vers train
# Copié: image4101.png vers train
# Copié: image4561.png vers train
# Copié: image4511.png vers train
# Copié: image4407.png vers train
# Copié: image3816.png vers train
# Copié: image4981.png vers train
# Copié: image4170.png vers train
# Copié: image4658.png vers train
# Copié: image4548.png vers train
# Copié: image3908.png vers train
# Copié: image4594.png vers train
# Copié: image3607.png vers train
# Copié: image4349.png vers train
# Copié: image4743.png vers train
# Copié: image4423.png vers train
# Copié: image4771.png vers train
# Copié: image3566.png vers train
# Copié: image3688.png vers train
# Copié: image4386.png vers train
# Copié: image4955.png vers train
# Copié: image4391.png vers train
# Copié: image3882.png vers train
# Copié: image4720.png vers train
# Copié: image3899.png vers train
# Copié: image4144.png vers train
# Copié: image3511.png vers train
# Copié: image3497.png vers train
# Copié: image4865.png vers train
# Copié: image3716.png vers train
# Copié: image3598.png vers train
# Copié: image4746.png vers train
# Copié: image4853.png vers train
# Copié: image3602.png vers train
# Copié: image4632.png vers train
# Copié: image4893.png vers train
# Copié: image4609.png vers train
# Copié: image4034.png vers train
# Copié: image4178.png vers train
# Copié: image4202.png vers train
# Copié: image3552.png vers train
# Copié: image4692.png vers train
# Copié: image4582.png vers train
# Copié: image4850.png vers train
# Copié: image4581.png vers train
# Copié: image4524.png vers train
# Copié: image3619.png vers train
# Copié: image4371.png vers train
# Copié: image3564.png vers train
# Copié: image4351.png vers train
# Copié: image3482.png vers train
# Copié: image4586.png vers train
# Copié: image3935.png vers train
# Copié: image4731.png vers train
# Copié: image4984.png vers train
# Copié: image3650.png vers train
# Copié: image4286.png vers train
# Copié: image3980.png vers train
# Copié: image3746.png vers train
# Copié: image4603.png vers train
# Copié: image3483.png vers train
# Copié: image3994.png vers train
# Copié: image3867.png vers train
# Copié: image3724.png vers train
# Copié: image3713.png vers train
# Copié: image4857.png vers train
# Copié: image3551.png vers train
# Copié: image4103.png vers train
# Copié: image4073.png vers train
# Copié: image4570.png vers train
# Copié: image4142.png vers train
# Copié: image3977.png vers train
# Copié: image4613.png vers train
# Copié: image4398.png vers train
# Copié: image3843.png vers train
# Copié: image4983.png vers train
# Copié: image4926.png vers train
# Copié: image3966.png vers train
# Copié: image3825.png vers train
# Copié: image4878.png vers train
# Copié: image3646.png vers train
# Copié: image4822.png vers train
# Copié: image3538.png vers train
# Copié: image3708.png vers train
# Copié: image3802.png vers train
# Copié: image3595.png vers train
# Copié: image4191.png vers train
# Copié: image4018.png vers train
# Copié: image3524.png vers train
# Copié: image4426.png vers train
# Copié: image3849.png vers train
# Copié: image4166.png vers train
# Copié: image4472.png vers train
# Copié: image3763.png vers train
# Copié: image4310.png vers train
# Copié: image4589.png vers train
# Copié: image3836.png vers train
# Copié: image4070.png vers train
# Copié: image4910.png vers train
# Copié: image3577.png vers train
# Copié: image4282.png vers train
# Copié: image4709.png vers train
# Copié: image4308.png vers train
# Copié: image3567.png vers train
# Copié: image4722.png vers train
# Copié: image4577.png vers train
# Copié: image4285.png vers train
# Copié: image4060.png vers train
# Copié: image3489.png vers train
# Copié: image4619.png vers train
# Copié: image3525.png vers train
# Copié: image4462.png vers train
# Copié: image4326.png vers train
# Copié: image3679.png vers train
# Copié: image3682.png vers train
# Copié: image4937.png vers train
# Copié: image4243.png vers train
# Copié: image3824.png vers train
# Copié: image4654.png vers train
# Copié: image4187.png vers train
# Copié: image3596.png vers train
# Copié: image4412.png vers train
# Copié: image4378.png vers train
# Copié: image4475.png vers train
# Copié: image3509.png vers train
# Copié: image3637.png vers train
# Copié: image4585.png vers train
# Copié: image4700.png vers train
# Copié: image4624.png vers train
# Copié: image4542.png vers train
# Copié: image4978.png vers train
# Copié: image4359.png vers train
# Copié: image3960.png vers train
# Copié: image4518.png vers train
# Copié: image3601.png vers train
# Copié: image3518.png vers train
# Copié: image4905.png vers train
# Copié: image4498.png vers train
# Copié: image3856.png vers train
# Copié: image3957.png vers train
# Copié: image3695.png vers train
# Copié: image3859.png vers train
# Copié: image4930.png vers train
# Copié: image4110.png vers train
# Copié: image4672.png vers train
# Copié: image4796.png vers train
# Copié: image3718.png vers train
# Copié: image4557.png vers train
# Copié: image4615.png vers train
# Copié: image3841.png vers train
# Copié: image3494.png vers train
# Copié: image4945.png vers train
# Copié: image3795.png vers train
# Copié: image3751.png vers train
# Copié: image4885.png vers train
# Copié: image3522.png vers train
# Copié: image4158.png vers train
# Copié: image3559.png vers train
# Copié: image4254.png vers train
# Copié: image3931.png vers train
# Copié: image4858.png vers train
# Copié: image3961.png vers train
# Copié: image4364.png vers train
# Copié: image4499.png vers train
# Copié: image4458.png vers train
# Copié: image3797.png vers train
# Copié: image4977.png vers train
# Copié: image4976.png vers train
# Copié: image4159.png vers train
# Copié: image4635.png vers train
# Copié: image4455.png vers train
# Copié: image4468.png vers train
# Copié: image4222.png vers train
# Copié: image4752.png vers train
# Copié: image3677.png vers train
# Copié: image3820.png vers train
# Copié: image4469.png vers train
# Copié: image3909.png vers train
# Copié: image3514.png vers train
# Copié: image4956.png vers train
# Copié: image4634.png vers train
# Copié: image4833.png vers train
# Copié: image4695.png vers train
# Copié: image4387.png vers train
# Copié: image4108.png vers train
# Copié: image4597.png vers train
# Copié: image4834.png vers train
# Copié: image4228.png vers train
# Copié: image4216.png vers train
# Copié: image4701.png vers train
# Copié: image3879.png vers train
# Copié: image3894.png vers train
# Copié: image4757.png vers train
# Copié: image3587.png vers train
# Copié: image4947.png vers train
# Copié: image4442.png vers train
# Copié: image4362.png vers train
# Copié: image3818.png vers train
# Copié: image4155.png vers train
# Copié: image4529.png vers train
# Copié: image3969.png vers train
# Copié: image4801.png vers train
# Copié: image4476.png vers train
# Copié: image4637.png vers train
# Copié: image4107.png vers train
# Copié: image3618.png vers train
# Copié: image4417.png vers train
# Copié: image3673.png vers train
# Copié: image4252.png vers train
# Copié: image3814.png vers train
# Copié: image3520.png vers train
# Copié: image4744.png vers train
# Copié: image3962.png vers train
# Copié: image4208.png vers train
# Copié: image4863.png vers train
# Copié: image4102.png vers train
# Copié: image3854.png vers train
# Copié: image3681.png vers train
# Copié: image3855.png vers train
# Copié: image3531.png vers train
# Copié: image3594.png vers train
# Copié: image4736.png vers train
# Copié: image4330.png vers train
# Copié: image3535.png vers train
# Copié: image3686.png vers train
# Copié: image4072.png vers train
# Copié: image4095.png vers train
# Copié: image4304.png vers train
# Copié: image4385.png vers train
# Copié: image3507.png vers train
# Copié: image3923.png vers train
# Copié: image4160.png vers train
# Copié: image4203.png vers train
# Copié: image3997.png vers train
# Copié: image4838.png vers train
# Copié: image3749.png vers train
# Copié: image4537.png vers train
# Copié: image3588.png vers train
# Copié: image4768.png vers train
# Copié: image4817.png vers train
# Copié: image4025.png vers train
# Copié: image4043.png vers train
# Copié: image3782.png vers train
# Copié: image4035.png vers train
# Copié: image3747.png vers train
# Copié: image3900.png vers train
# Copié: image3953.png vers train
# Copié: image4411.png vers train
# Copié: image3759.png vers train
# Copié: image3510.png vers train
# Copié: image4656.png vers train
# Copié: image3687.png vers train
# Copié: image4130.png vers train
# Copié: image4300.png vers train
# Copié: image4075.png vers train
# Copié: image4196.png vers train
# Copié: image4681.png vers train
# Copié: image4352.png vers train
# Copié: image4653.png vers train
# Copié: image4127.png vers train
# Copié: image3770.png vers train
# Copié: image4837.png vers train
# Copié: image3942.png vers train
# Copié: image4206.png vers train
# Copié: image4696.png vers train
# Copié: image3864.png vers train
# Copié: image3705.png vers train
# Copié: image3533.png vers train
# Copié: image3542.png vers train
# Copié: image3638.png vers train
# Copié: image4210.png vers train
# Copié: image3752.png vers train
# Copié: image3785.png vers train
# Copié: image3965.png vers train
# Copié: image4463.png vers train
# Copié: image3669.png vers train
# Copié: image4786.png vers train
# Copié: image4226.png vers train
# Copié: image3730.png vers train
# Copié: image4969.png vers train
# Copié: image3821.png vers train
# Copié: image4149.png vers train
# Copié: image3541.png vers train
# Copié: image3920.png vers train
# Copié: image4683.png vers train
# Copié: image4601.png vers train
# Copié: image3807.png vers train
# Copié: image4502.png vers train
# Copié: image4986.png vers train
# Copié: image3873.png vers train
# Copié: image4113.png vers train
# Copié: image4486.png vers train
# Copié: image3502.png vers train
# Copié: image4221.png vers train
# Copié: image3819.png vers train
# Copié: image4050.png vers train
# Copié: image3753.png vers train
# Copié: image4544.png vers train
# Copié: image4889.png vers train
# Copié: image4154.png vers train
# Copié: image3568.png vers train
# Copié: image4973.png vers train
# Copié: image4628.png vers train
# Copié: image4549.png vers train
# Copié: image4526.png vers train
# Copié: image4915.png vers train
# Copié: image4274.png vers train
# Copié: image4946.png vers train
# Copié: image3517.png vers train
# Copié: image4279.png vers train
# Copié: image4334.png vers train
# Copié: image4259.png vers train
# Copié: image4219.png vers train
# Copié: image4307.png vers train
# Copié: image3922.png vers train
# Copié: image4338.png vers train
# Copié: image3492.png vers train
# Copié: image4621.png vers train
# Copié: image3678.png vers train
# Copié: image3707.png vers train
# Copié: image3956.png vers train
# Copié: image4566.png vers train
# Copié: image4873.png vers train
# Copié: image4190.png vers train
# Copié: image3704.png vers train
# Copié: image4311.png vers train
# Copié: image3689.png vers train
# Copié: image3666.png vers train
# Copié: image3526.png vers train
# Copié: image3647.png vers train
# Copié: image3939.png vers train
# Copié: image4642.png vers train
# Copié: image3478.png vers train
# Copié: image4445.png vers train
# Copié: image4145.png vers train
# Copié: image4173.png vers train
# Copié: image3767.png vers train
# Copié: image3787.png vers train
# Copié: image4319.png vers train
# Copié: image3828.png vers train
# Copié: image4046.png vers train
# Copié: image4710.png vers train
# Copié: image4897.png vers train
# Copié: image4134.png vers train
# Copié: image3986.png vers train
# Copié: image4029.png vers train
# Copié: image4168.png vers train
# Copié: image4440.png vers train
# Copié: image3723.png vers train
# Copié: image4874.png vers train
# Copié: image4118.png vers train
# Copié: image4564.png vers train
# Copié: image4690.png vers train
# Copié: image4245.png vers train
# Copié: image4728.png vers train
# Copié: image4761.png vers train
# Copié: image3621.png vers train
# Copié: image3774.png vers train
# Copié: image4182.png vers train
# Copié: image4673.png vers train
# Copié: image4396.png vers train
# Copié: image3830.png vers train
# Copié: image4568.png vers train
# Copié: image3946.png vers train
# Copié: image4497.png vers train
# Copié: image3676.png vers train
# Copié: image3570.png vers train
# Copié: image4911.png vers train
# Copié: image3915.png vers train
# Copié: image4877.png vers train
# Copié: image4645.png vers train
# Copié: image4492.png vers train
# Copié: image4294.png vers train
# Copié: image4712.png vers train
# Copié: image4694.png vers train
# Copié: image4782.png vers train
# Copié: image4091.png vers train
# Copié: image4531.png vers train
# Copié: image4241.png vers train
# Copié: image4517.png vers train
# Copié: image4424.png vers train
# Copié: image4461.png vers train
# Copié: image3532.png vers train
# Copié: image3572.png vers train
# Copié: image4958.png vers train
# Copié: image3926.png vers train
# Copié: image4726.png vers train
# Copié: image3530.png vers train
# Copié: image4697.png vers train
# Copié: image3757.png vers train
# Copié: image4831.png vers train
# Copié: image3913.png vers train
# Copié: image4459.png vers train
# Copié: image4020.png vers train
# Copié: image4732.png vers train
# Copié: image4551.png vers train
# Copié: image4916.png vers train
# Copié: image4571.png vers train
# Copié: image4546.png vers train
# Copié: image4545.png vers train
# Copié: image3696.png vers train
# Copié: image3812.png vers train
# Copié: image3701.png vers train
# Copié: image3617.png vers train
# Copié: image3614.png vers train
# Copié: image3912.png vers train
# Copié: image3903.png vers train
# Copié: image4618.png vers train
# Copié: image4970.png vers train
# Copié: image4231.png vers train
# Copié: image4410.png vers train
# Copié: image3581.png vers train
# Copié: image4795.png vers train
# Copié: image4186.png vers train
# Copié: image4864.png vers train
# Copié: image4456.png vers train
# Copié: image3555.png vers train
# Copié: image4449.png vers train
# Copié: image3898.png vers train
# Copié: image3672.png vers train
# Copié: image3721.png vers train
# Copié: image4379.png vers train
# Copié: image4860.png vers train
# Copié: image4514.png vers train
# Copié: image4369.png vers train
# Copié: image4125.png vers train
# Copié: image4921.png vers train
# Copié: image4263.png vers train
# Copié: image4738.png vers train
# Copié: image3941.png vers train
# Copié: image4375.png vers train
# Copié: image4420.png vers train
# Copié: image3822.png vers train
# Copié: image3743.png vers train
# Copié: image4318.png vers train
# Copié: image3648.png vers train
# Copié: image4682.png vers train
# Copié: image3697.png vers train
# Copié: image3500.png vers train
# Copié: image4985.png vers train
# Copié: image3586.png vers train
# Copié: image4725.png vers train
# Copié: image4098.png vers train
# Copié: image4447.png vers train
# Copié: image4293.png vers train
# Copié: image4830.png vers train
# Copié: image4996.png vers train
# Copié: image4913.png vers train
# Copié: image4515.png vers train
# Copié: image4840.png vers train
# Copié: image3769.png vers train
# Copié: image4938.png vers train
# Copié: image3592.png vers train
# Copié: image3762.png vers train
# Copié: image3861.png vers train
# Copié: image4852.png vers train
# Copié: image4157.png vers train
# Copié: image3600.png vers train
# Copié: image4389.png vers train
# Copié: image4061.png vers train
# Copié: image3936.png vers train
# Copié: image4224.png vers train
# Copié: image4968.png vers train
# Copié: image3656.png vers train
# Copié: image4354.png vers train
# Copié: image4465.png vers train
# Copié: image3579.png vers train
# Copié: image4512.png vers train
# Copié: image4820.png vers train
# Copié: image4827.png vers train
# Copié: image4233.png vers train
# Copié: image4363.png vers train
# Copié: image3862.png vers train
# Copié: image4438.png vers train
# Copié: image4741.png vers train
# Copié: image4770.png vers train
# Copié: image4011.png vers train
# Copié: image3815.png vers train
# Copié: image4466.png vers train
# Copié: image4651.png vers train
# Copié: image3680.png vers train
# Copié: image4610.png vers train
# Copié: image3741.png vers train
# Copié: image4068.png vers train
# Copié: image4787.png vers train
# Copié: image4048.png vers train
# Copié: image3765.png vers train
# Copié: image3766.png vers train
# Copié: image4348.png vers train
# Copié: image3664.png vers train
# Copié: image4816.png vers train
# Copié: image4936.png vers train
# Copié: image4713.png vers train
# Copié: image4688.png vers train
# Copié: image4608.png vers train
# Copié: image3720.png vers train
# Copié: image4507.png vers train
# Copié: image4943.png vers train
# Copié: image3831.png vers train
# Copié: image4247.png vers train
# Copié: image3683.png vers train
# Copié: image4848.png vers train
# Copié: image3557.png vers train
# Copié: image4137.png vers train
# Copié: image3853.png vers train
# Copié: image4565.png vers train
# Copié: image4287.png vers train
# Copié: image4826.png vers train
# Copié: image4558.png vers train
# Copié: image3589.png vers train
# Copié: image4272.png vers train
# Copié: image4014.png vers train
# Copié: image4665.png vers train
# Copié: image3620.png vers train
# Copié: image4239.png vers train
# Copié: image4430.png vers train
# Copié: image4888.png vers train
# Copié: image4248.png vers train
# Copié: image4236.png vers train
# Copié: image3529.png vers train
# Copié: image4481.png vers train
# Copié: image4443.png vers train
# Copié: image4027.png vers train
# Copié: image4051.png vers train
# Copié: image3712.png vers train
# Copié: image3625.png vers train
# Copié: image3488.png vers train
# Copié: image4859.png vers train
# Copié: image3933.png vers train
# Copié: image4617.png vers train
# Copié: image3629.png vers train
# Copié: image4825.png vers train
# Copié: image4053.png vers train
# Copié: image4302.png vers train
# Copié: image4699.png vers train
# Copié: image4919.png vers train
# Copié: image4908.png vers train
# Copié: image4974.png vers train
# Copié: image4995.png vers train
# Copié: image4477.png vers train
# Copié: image4552.png vers train
# Copié: image3604.png vers train
# Copié: image4397.png vers train
# Copié: image4929.png vers train
# Copié: image3515.png vers train
# Copié: image4156.png vers train
# Copié: image4505.png vers train
# Copié: image4111.png vers train
# Copié: image4056.png vers train
# Copié: image3917.png vers train
# Copié: image4332.png vers train
# Copié: image3845.png vers train
# Copié: image4832.png vers train
# Copié: image3590.png vers train
# Copié: image4036.png vers train
# Copié: image3711.png vers train
# Copié: image3491.png vers train
# Copié: image3660.png vers train
# Copié: image3710.png vers train
# Copié: image3875.png vers train
# Copié: image4315.png vers train
# Copié: image3929.png vers train
# Copié: image3630.png vers train
# Copié: image4939.png vers train
# Copié: image4265.png vers train
# Copié: image4843.png vers train
# Copié: image3670.png vers train
# Copié: image4370.png vers train
# Copié: image3756.png vers train
# Copié: image3870.png vers train
# Copié: image3694.png vers train
# Copié: image4288.png vers train
# Copié: image4135.png vers train
# Copié: image4785.png vers train
# Copié: image4055.png vers train
# Copié: image4000.png vers train
# Copié: image4413.png vers train
# Copié: image3914.png vers train
# Copié: image4415.png vers train
# Copié: image4543.png vers train
# Copié: image4408.png vers train
# Copié: image4099.png vers train
# Copié: image4211.png vers train
# Copié: image3761.png vers train
# Copié: image4401.png vers train
# Copié: image3897.png vers train
# Copié: image3702.png vers train
# Copié: image3521.png vers train
# Copié: image4305.png vers train
# Copié: image4595.png vers train
# Copié: image3699.png vers train
# Copié: image4815.png vers train
# Copié: image3512.png vers train
# Copié: image4429.png vers train
# Copié: image4661.png vers train
# Copié: image4758.png vers train
# Copié: image4579.png vers train
# Copié: image3810.png vers train
# Copié: image4766.png vers train
# Copié: image4049.png vers train
# Copié: image3691.png vers train
# Copié: image3992.png vers train
# Copié: image4309.png vers train
# Copié: image4235.png vers train
# Copié: image3792.png vers train
# Copié: image4414.png vers train
# Copié: image4451.png vers train
# Copié: image4742.png vers train
# Copié: image3959.png vers train
# Copié: image4275.png vers train
# Copié: image4574.png vers train
# Copié: image4829.png vers train
# Copié: image4361.png vers train
# Copié: image4778.png vers train
# Copié: image4807.png vers train
# Copié: image4446.png vers train
# Copié: image3928.png vers train
# Copié: image4234.png vers train
# Copié: image4799.png vers train
# Copié: image3548.png vers train
# Copié: image4478.png vers train
# Copié: image4380.png vers train
# Copié: image4679.png vers train
# Copié: image4493.png vers train
# Copié: image3887.png vers train
# Copié: image3934.png vers train
# Copié: image4131.png vers train
# Copié: image4640.png vers train
# Copié: image4152.png vers train
# Copié: image4350.png vers train
# Copié: image4647.png vers train
# Copié: image4979.png vers train
# Copié: image4798.png vers train
# Copié: image4814.png vers train
# Copié: image4071.png vers train
# Copié: image3591.png vers train
# Copié: image4781.png vers train
# Copié: image4724.png vers train
# Copié: image4002.png vers train
# Copié: image4821.png vers train
# Copié: image4510.png vers train
# Copié: image3860.png vers train
# Copié: image4039.png vers train
# Copié: image4861.png vers train
# Copié: image4045.png vers train
# Copié: image4940.png vers train
# Copié: image3516.png vers train
# Copié: image3865.png vers train
# Copié: image4017.png vers train
# Copié: image3612.png vers train
# Copié: image4278.png vers train
# Copié: image4316.png vers train
# Copié: image4538.png vers train
# Copié: image4580.png vers train
# Copié: image4284.png vers train
# Copié: image3990.png vers train
# Copié: image4297.png vers train
# Copié: image4261.png vers train
# Copié: image4527.png vers train
# Copié: image3733.png vers train
# Copié: image3558.png vers train
# Copié: image4847.png vers train
# Copié: image3916.png vers train
# Copié: image4952.png vers train
# Copié: image3569.png vers train
# Copié: image4539.png vers train
# Copié: image4530.png vers train
# Copié: image4593.png vers train
# Copié: image4686.png vers train
# Copié: image3938.png vers train
# Copié: image4715.png vers train
# Copié: image4078.png vers train
# Copié: image4013.png vers train
# Copié: image3993.png vers train
# Copié: image4116.png vers train
# Copié: image4174.png vers train
# Copié: image4460.png vers train
# Copié: image4479.png vers train
# Copié: image3528.png vers train
# Copié: image4021.png vers train
# Copié: image4490.png vers train
# Copié: image3484.png vers train
# Copié: image4989.png vers train
# Copié: image4090.png vers train
# Copié: image4520.png vers train
# Copié: image4192.png vers train
# Copié: image4516.png vers train
# Copié: image4355.png vers train
# Copié: image4789.png vers train
# Copié: image4303.png vers train
# Copié: image4790.png vers train
# Copié: image4353.png vers train
# Copié: image4329.png vers train
# Copié: image4001.png vers train
# Copié: image3698.png vers train
# Copié: image4038.png vers train
# Copié: image3706.png vers train
# Copié: image4019.png vers train
# Copié: image3918.png vers train
# Copié: image4931.png vers train
# Copié: image3505.png vers train
# Copié: image4765.png vers train
# Copié: image4944.png vers train
# Copié: image4100.png vers train
# Copié: image3954.png vers train
# Copié: image3885.png vers train
# Copié: image3846.png vers train
# Copié: image4062.png vers train
# Copié: image3852.png vers train
# Copié: image3651.png vers train
# Copié: image4080.png vers train
# Copié: image3927.png vers train
# Copié: image4256.png vers train
# Copié: image3736.png vers train
# Copié: image4756.png vers train
# Copié: image3506.png vers train
# Copié: image4383.png vers train
# Copié: image3947.png vers train
# Copié: image3486.png vers train
# Copié: image4162.png vers train
# Copié: image4772.png vers train
# Copié: image4485.png vers train
# Copié: image3793.png vers train
# Copié: image3951.png vers train
# Copié: image4077.png vers train
# Copié: image4176.png vers train
# Copié: image4403.png vers train
# Copié: image4717.png vers train
# Copié: image3631.png vers train
# Copié: image4560.png vers train
# Copié: image4032.png vers train
# Copié: image4273.png vers train
# Copié: image4880.png vers train
# Copié: image3504.png vers train
# Copié: image4205.png vers train
# Copié: image4922.png vers train
# Copié: image3886.png vers train
# Copié: image4806.png vers train
# Copié: image3654.png vers train
# Copié: image4143.png vers train
# Copié: image3948.png vers train
# Copié: image4433.png vers train
# Copié: image4085.png vers train
# Copié: image4960.png vers train
# Copié: image4435.png vers train
# Copié: image3493.png vers train
# Copié: image4333.png vers train
# Copié: image3641.png vers train
# Copié: image3729.png vers train
# Copié: image4677.png vers train
# Copié: image4997.png vers train
# Copié: image4975.png vers train
# Copié: image4556.png vers train
# Copié: image4450.png vers train
# Copié: image4148.png vers train
# Copié: image3833.png vers train
# Copié: image3975.png vers train
# Copié: image3499.png vers train
# Copié: image3709.png vers train
# Copié: image4780.png vers train
# Copié: image4662.png vers train
# Copié: image3605.png vers train
# Copié: image4120.png vers train
# Copié: image4377.png vers train
# Copié: image4343.png vers train
# Copié: image4914.png vers train
# Copié: image4912.png vers train
# Copié: image4008.png vers train
# Copié: image4337.png vers train
# Copié: image4280.png vers train
# Copié: image4164.png vers train
# Copié: image4764.png vers train
# Copié: image4441.png vers train
# Copié: image4754.png vers train
# Copié: image4649.png vers train
# Copié: image4295.png vers train
# Copié: image3606.png vers train
# Copié: image4022.png vers train
# Copié: image3633.png vers train
# Copié: image4652.png vers train
# Copié: image4400.png vers train
# Copié: image4434.png vers train
# Copié: image4339.png vers train
# Copié: image3930.png vers train
# Copié: image4147.png vers train
# Copié: image4903.png vers train
# Copié: image4755.png vers train
# Copié: image4388.png vers train
# Copié: image3501.png vers train
# Copié: image4991.png vers train
# Copié: image4733.png vers train
# Copié: image3560.png vers train
# Copié: image4890.png vers train
# Copié: image3662.png vers train
# Copié: image3760.png vers train
# Copié: image4112.png vers train
# Copié: image4382.png vers train
# Copié: image3985.png vers train
# Copié: image4067.png vers train
# Copié: image3827.png vers train
# Copié: image3796.png vers train
# Copié: image4229.png vers train
# Copié: image4007.png vers train
# Copié: image4706.png vers train
# Copié: image3653.png vers train
# Copié: image3565.png vers train
# Copié: image4614.png vers train
# Copié: image4547.png vers train
# Copié: image3799.png vers train
# Copié: image3803.png vers train
# Copié: image4358.png vers train
# Copié: image3693.png vers train
# Copié: image4059.png vers train
# Copié: image4041.png vers train
# Copié: image3866.png vers train
# Copié: image4804.png vers train
# Copié: image4891.png vers train
# Copié: image3872.png vers train
# Copié: image4336.png vers train
# Copié: image4730.png vers train
# Copié: image4759.png vers train
# Copié: image4392.png vers train
# Copié: image4727.png vers train
# Copié: image4932.png vers train
# Copié: image4925.png vers train
# Copié: image4313.png vers train
# Copié: image3823.png vers train
# Copié: image3608.png vers train
# Copié: image4432.png vers train
# Copié: image4317.png vers train
# Copié: image4276.png vers train
# Copié: image4927.png vers train
# Copié: image3999.png vers train
# Copié: image3790.png vers train
# Copié: image3889.png vers train
# Copié: image3685.png vers train
# Copié: image3652.png vers train
# Copié: image3940.png vers train
# Copié: image4536.png vers train
# Copié: image4898.png vers train
# Copié: image4082.png vers train
# Copié: image3537.png vers train
# Copié: image4464.png vers train
# Copié: image3739.png vers train
# Copié: image3563.png vers train
# Copié: image3791.png vers train
# Copié: image3593.png vers train
# Copié: image4483.png vers train
# Copié: image4783.png vers train
# Copié: image4471.png vers train
# Copié: image3728.png vers train
# Copié: image3599.png vers train
# Copié: image4763.png vers train
# Copié: image4390.png vers train
# Copié: image4844.png vers train
# Copié: image4198.png vers train
# Copié: image4366.png vers train
# Copié: image4163.png vers train
# Copié: image3556.png vers train
# Copié: image4004.png vers train
# Copié: image4042.png vers train
# Copié: image4508.png vers train
# Copié: image4153.png vers train
# Copié: image3536.png vers train
# Copié: image3901.png vers train
# Copié: image4962.png vers train
# Copié: image4676.png vers train
# Copié: image3643.png vers train
# Copié: image4663.png vers train
# Copié: image4994.png vers train
# Copié: image4105.png vers train
# Copié: image3616.png vers train
# Copié: image4093.png vers train
# Copié: image4767.png vers train
# Copié: image3609.png vers train
# Copié: image4506.png vers train
# Copié: image4271.png vers train
# Copié: image3543.png vers train
# Copié: image3890.png vers train
# Copié: image4525.png vers train
# Copié: image4487.png vers train
# Copié: image4132.png vers train
# Copié: image3585.png vers train
# Copié: image4344.png vers train
# Copié: image4141.png vers train
# Copié: image4963.png vers train
# Copié: image4373.png vers train
# Copié: image4260.png vers train
# Copié: image4262.png vers train
# Copié: image4559.png vers train
# Copié: image3745.png vers train
# Copié: image4941.png vers train
# Copié: image3925.png vers train
# Copié: image4650.png vers train
# Copié: image4762.png vers train
# Copié: image4967.png vers train
# Copié: image4452.png vers train
# Copié: image4866.png vers train
# Copié: image4886.png vers train
# Copié: image3611.png vers train
# Copié: image4422.png vers train
# Copié: image4519.png vers train
# Copié: image4729.png vers train
# Copié: image3719.png vers train
# Copié: image3932.png vers train
# Copié: image3758.png vers train
# Copié: image4114.png vers train
# Copié: image3905.png vers train
# Copié: image4909.png vers train
# Copié: image4195.png vers train
# Copié: image3906.png vers train
# Copié: image4723.png vers train
# Copié: image4818.png vers train
# Copié: image4491.png vers train
# Copié: image4010.png vers train
# Copié: image4306.png vers train
# Copié: image4961.png vers train
# Copié: image4024.png vers train
# Copié: image4813.png vers train
# Copié: image3968.png vers train
# Copié: image4488.png vers train
# Copié: image4406.png vers train
# Copié: image3737.png vers train
# Copié: image3786.png vers train
# Copié: image3597.png vers train
# Copié: image4140.png vers train
# Copié: image4812.png vers train
# Copié: image4739.png vers train
# Copié: image4299.png vers train
# Copié: image4884.png vers train
# Copié: image4554.png vers train
# Copié: image4896.png vers train
# Copié: image3772.png vers train
# Copié: image3971.png vers train
# Copié: image4627.png vers train
# Copié: image4809.png vers train
# Copié: image3715.png vers train
# Copié: image4769.png vers train
# Copié: image4596.png vers train
# Copié: image4033.png vers train
# Copié: image3754.png vers train
# Copié: image4342.png vers train
# Copié: image4666.png vers train
# Copié: image3610.png vers train
# Copié: image3628.png vers train
# Copié: image3876.png vers train
# Copié: image3945.png vers train
# Copié: image3776.png vers train
# Copié: image4534.png vers train
# Copié: image4667.png vers train
# Copié: image4028.png vers train
# Copié: image3479.png vers train
# Copié: image3813.png vers train
# Copié: image4745.png vers train
# Copié: image4824.png vers train
# Copié: image3583.png vers train
# Copié: image4775.png vers train
# Copié: image4719.png vers train
# Copié: image4625.png vers train
# Copié: image3575.png vers train
# Copié: image4881.png vers train
# Copié: image4928.png vers train
# Copié: image4323.png vers train
# Copié: image4794.png vers train
# Copié: image4136.png vers train
# Copié: image3826.png vers train
# Copié: image3919.png vers train
# Copié: image4194.png vers train
# Copié: image3883.png vers train
# Copié: image4237.png vers train
# Copié: image4521.png vers train
# Copié: image3476.png vers train
# Copié: image4788.png vers train
# Copié: image3668.png vers train
# Copié: image4146.png vers train
# Copié: image4689.png vers train
# Copié: image3692.png vers train
# Copié: image4533.png vers train
# Copié: image4394.png vers train
# Copié: image4207.png vers train
# Copié: image4990.png vers train
# Copié: image4083.png vers train
# Copié: image3725.png vers train
# Copié: image4876.png vers train
# Copié: image4562.png vers train
# Copié: image4117.png vers train
# Copié: image4106.png vers train
# Copié: image3571.png vers train
# Copié: image4917.png vers train
# Copié: image3783.png vers train
# Copié: image3847.png vers train
# Copié: image4535.png vers train
# Copié: image4611.png vers train
# Copié: image4298.png vers train
# Copié: image4664.png vers train
# Copié: image4381.png vers train
# Copié: image3671.png vers train
# Copié: image3857.png vers train
# Copié: image4230.png vers train
# Copié: image3871.png vers train
# Copié: image4096.png vers train
# Copié: image4065.png vers train
# Copié: image4138.png vers train
# Copié: image4074.png vers train
# Copié: image3731.png vers train
# Copié: image4225.png vers train
# Copié: image4500.png vers train
# Copié: image3480.png vers train
# Copié: image3869.png vers train
# Copié: image3632.png vers train
# Copié: image4180.png vers train
# Copié: image4016.png vers train
# Copié: image3544.png vers train
# Copié: image4185.png vers train
# Copié: image4918.png vers train
# Copié: image4193.png vers train
# Copié: image3519.png vers train
# Copié: image4006.png vers train
# Copié: image4268.png vers train
# Copié: image4092.png vers train
# Copié: image4900.png vers train
# Copié: image3562.png vers train
# Copié: image4550.png vers train
# Copié: image4698.png vers train
# Copié: image4139.png vers train
# Copié: image4707.png vers train
# Copié: image4470.png vers train
# Copié: image4393.png vers train
# Copié: image3804.png vers train
# Copié: image3534.png vers train
# Copié: image4184.png vers train
# Copié: image3839.png vers train
# Copié: image4183.png vers train
# Copié: image3740.png vers train
# Copié: image3640.png vers train
# Copié: image4495.png vers train
# Copié: image4569.png vers train
# Copié: image3726.png vers train
# Copié: image4802.png vers train
# Copié: image4948.png vers train
# Copié: image3550.png vers train
# Copié: image3949.png vers train
# Copié: image4553.png vers train
# Copié: image4879.png vers train
# Copié: image3636.png vers train
# Copié: image4009.png vers train
# ...
# Copié: image3624.png vers val
# Copié: image4501.png vers val
# Copié: image3722.png vers val
# Copié: image3742.png vers val
# Copié: image3808.png vers val
# Copié: image4584.png vers val
# Copié: image4892.png vers val
# Copié: image4264.png vers val
# Copié: image4289.png vers val
# Copié: image4119.png vers val
# Copié: image3684.png vers val
# Copié: image4680.png vers val
# Copié: image3970.png vers val
# Copié: image3844.png vers val
# Copié: image4437.png vers val
# Copié: image3789.png vers val
# Copié: image4453.png vers val
# Copié: image4151.png vers val
# Copié: image3727.png vers val
# Copié: image4563.png vers val
# Copié: image4197.png vers val
# Copié: image3503.png vers val
# Copié: image4702.png vers val
# Copié: image4244.png vers val
# Copié: image4532.png vers val
# Copié: image4870.png vers val
# Copié: image4648.png vers val
# Copié: image4345.png vers val
# Copié: image3850.png vers val
# Copié: image4242.png vers val
# Copié: image3911.png vers val
# Copié: image3554.png vers val
# Copié: image4875.png vers val
# Copié: image4721.png vers val
# Copié: image4444.png vers val
# Copié: image4189.png vers val
# Copié: image3910.png vers val
# Copié: image4081.png vers val
# Copié: image4322.png vers val
# Copié: image4296.png vers val
# Copié: image3635.png vers val
# Copié: image3973.png vers val
# Copié: image3750.png vers val
# Copié: image3690.png vers val
# Copié: image4935.png vers val
# Copié: image4395.png vers val
# Copié: image4177.png vers val
# Copié: image4509.png vers val
# Copié: image4240.png vers val
# Copié: image4623.png vers val
# Copié: image4115.png vers val
# Copié: image4972.png vers val
# Copié: image4258.png vers val
# Copié: image4292.png vers val
# Copié: image4629.png vers val
# Copié: image4291.png vers val
# Copié: image4188.png vers val
# Copié: image4448.png vers val
# Copié: image4418.png vers val
# Copié: image4734.png vers val
# Copié: image4842.png vers val
# Copié: image4504.png vers val
# Copié: image4631.png vers val
# Copié: image3805.png vers val
# Copié: image4575.png vers val
# Copié: image3972.png vers val
# Copié: image4040.png vers val
# Copié: image3659.png vers val
# Copié: image4214.png vers val
# Copié: image4587.png vers val
# Copié: image4270.png vers val
# Copié: image4199.png vers val
# Copié: image4213.png vers val
# Copié: image4474.png vers val
# Copié: image4384.png vers val
# Copié: image4266.png vers val
# Copié: image4641.png vers val
# Copié: image3658.png vers val
# Copié: image4823.png vers val
# Copié: image4496.png vers val
# Copié: image3784.png vers val
# Copié: image4773.png vers val
# Copié: image4331.png vers val
# Copié: image3738.png vers val
# Copié: image4066.png vers val
# Copié: image4281.png vers val
# Copié: image4797.png vers val
# Copié: image4644.png vers val
# Copié: image4982.png vers val
# Copié: image3744.png vers val
# Copié: image3967.png vers val
# Copié: image3748.png vers val
# Copié: image4872.png vers val
# Copié: image3811.png vers val
# Copié: image3634.png vers val
# Copié: image4708.png vers val
# Copié: image3893.png vers val
# Copié: image3485.png vers val
# Copié: image3775.png vers val
# Copié: image4301.png vers val
# Copié: image4457.png vers val
# Copié: image4368.png vers val
# Copié: image4578.png vers val
# Copié: image3858.png vers val
# Copié: image3880.png vers val
# Copié: image3663.png vers val
# Copié: image4257.png vers val
# Copié: image3546.png vers val
# Copié: image3892.png vers val
# Copié: image4819.png vers val
# Copié: image3508.png vers val
# Copié: image4964.png vers val
# Copié: image4480.png vers val
# Copié: image3835.png vers val
# Copié: image3582.png vers val
# Copié: image3904.png vers val
# Copié: image4376.png vers val
# Copié: image4714.png vers val
# Copié: image4633.png vers val
# Copié: image3714.png vers val
# Copié: image4227.png vers val
# Copié: image4953.png vers val
# Copié: image4104.png vers val
# Copié: image3888.png vers val
# Copié: image4987.png vers val
# Copié: image4171.png vers val
# Copié: image4523.png vers val
# Copié: image3902.png vers val
# Copié: image4924.png vers val
# Copié: image3642.png vers val
# Copié: image4646.png vers val
# Copié: image4340.png vers val
# Copié: image3717.png vers val
# Copié: image4576.png vers val
# Copié: image4425.png vers val
# Copié: image4855.png vers val
# Copié: image4670.png vers val
# Copié: image4592.png vers val
# Copié: image4087.png vers val
# Copié: image4175.png vers val
# Copié: image4123.png vers val
# Copié: image4704.png vers val
# Copié: image3735.png vers val
# Copié: image4320.png vers val
# Copié: image4122.png vers val
# Copié: image4399.png vers val
# Copié: image3547.png vers val
# Copié: image4904.png vers val
# Copié: image3496.png vers val
# Copié: image4467.png vers val
# Copié: image4638.png vers val
# Copié: image4250.png vers val
# Copié: image4181.png vers val
# Copié: image4054.png vers val
# Copié: image3981.png vers val
# Copié: image4902.png vers val
# Copié: image4895.png vers val
# Copié: image4094.png vers val
# Copié: image3987.png vers val
# Copié: image3615.png vers val
# Copié: image3832.png vers val
# Copié: image4920.png vers val
# Copié: image3779.png vers val
# Copié: image4069.png vers val
# Copié: image4668.png vers val
# Copié: image4367.png vers val
# Copié: image4882.png vers val
# Copié: image4076.png vers val
# Copié: image4374.png vers val
# Copié: image4971.png vers val
# Copié: image3780.png vers val
# Copié: image4999.png vers val
# Copié: image4965.png vers val
# Copié: image4172.png vers val
# Copié: image4454.png vers val
# Copié: image4088.png vers val
# Copié: image4167.png vers val
# Copié: image4555.png vers val
# Copié: image4643.png vers val
# Copié: image3732.png vers val
# Copié: image3755.png vers val
# Copié: image4179.png vers val
# Copié: image4079.png vers val
# Copié: image4793.png vers val
# Copié: image4269.png vers val
# Copié: image4988.png vers val
# Copié: image3943.png vers val
# Copié: image3996.png vers val
# Copié: image4735.png vers val
# Copié: image3982.png vers val
# Copié: image4751.png vers val
# Copié: image4372.png vers val
# Copié: image4749.png vers val
# Copié: image3622.png vers val
# Copié: image4607.png vers val
# Copié: image4777.png vers val
# Copié: image3976.png vers val
# Copié: image4951.png vers val
# Copié: image4402.png vers val
# Copié: image3623.png vers val
# Copié: image4588.png vers val
# Copié: image4583.png vers val
# Copié: image3574.png vers val
# Copié: image4204.png vers val
# Copié: image3477.png vers val
# Copié: image3553.png vers val
# Copié: image4954.png vers val
# Copié: image4540.png vers val
# Copié: image4899.png vers val
# Copié: image3498.png vers val
# Copié: image4341.png vers val
# Copié: image4685.png vers val
# Copié: image4605.png vers val
# Copié: image4031.png vers val
# Copié: image4290.png vers val
# Copié: image4567.png vers val
# Copié: image4347.png vers val
# Copié: image4249.png vers val
# Copié: image4901.png vers val
# Copié: image4705.png vers val
# Copié: image4590.png vers val
# Copié: image4810.png vers val
# Copié: image3639.png vers val
# Copié: image3644.png vers val
# Copié: image4084.png vers val
# Copié: image3778.png vers val
# Copié: image3794.png vers val
# Copié: image4604.png vers val
# Copié: image4894.png vers val
# Copié: image3958.png vers val
# Copié: image3475.png vers val
# Copié: image4980.png vers val
# Copié: image4427.png vers val
# Copié: image4753.png vers val
# Copié: image3578.png vers val
# Copié: image3877.png vers val
# Copié: image4220.png vers val
# Copié: image4003.png vers val
# Copié: image4887.png vers val
# Copié: image4800.png vers val
# Copié: image3523.png vers val
# Copié: image4255.png vers val
# Copié: image4012.png vers val
# Copié: image4659.png vers val
# Copié: image4805.png vers val
# Copié: image3863.png vers val
# Copié: image3773.png vers val
# Copié: image3974.png vers val
# Copié: image4217.png vers val
# Copié: image3626.png vers val
# Copié: image3545.png vers val
# Copié: image3998.png vers val
# Copié: image3561.png vers val
# Copié: image4360.png vers val
# Copié: image4097.png vers val
# Copié: image4503.png vers val
# Copié: image4998.png vers val
# Copié: image4828.png vers val
# Copié: image3764.png vers val
# Copié: image4416.png vers val
# Copié: image4660.png vers val
# Copié: image4703.png vers val
# Copié: image3490.png vers val
# Copié: image3495.png vers val
# Copié: image4419.png vers val
# Copié: image4109.png vers val
# Copié: image3487.png vers val
# Copié: image4312.png vers val
# Copié: image3837.png vers val
# Copié: image4716.png vers val
# Copié: image4089.png vers val
# Copié: image3665.png vers val
# Copié: image3944.png vers val
# Copié: image3513.png vers val
# Copié: image4522.png vers val
# Copié: image4871.png vers val
# Copié: image4030.png vers val
# Copié: image4528.png vers val
# Copié: image4121.png vers val
# Copié: image4129.png vers val
# Copié: image3703.png vers val
# Copié: image4047.png vers val
# Copié: image3700.png vers val
# Copié: image4044.png vers val
# Copié: image4439.png vers val
# Copié: image4431.png vers val
# Copié: image4405.png vers val
# Copié: image3838.png vers val
# Copié: image4161.png vers val
# Copié: image3964.png vers val
# Copié: image4630.png vers val
# Copié: image4748.png vers val
# Copié: image3481.png vers val
# Copié: image4026.png vers val
# Copié: image4684.png vers val
# Copié: image3768.png vers val
# Copié: image3868.png vers val
# Copié: image3809.png vers val
# Copié: image4791.png vers val
# Copié: image4165.png vers val
# Copié: image4841.png vers val
# Copié: image4232.png vers val
# Copié: image4283.png vers val
# Copié: image4779.png vers val
# Copié: image3788.png vers val
# Copié: image3624.png vers val
# Copié: image4501.png vers val
# Copié: image3722.png vers val
# Copié: image3742.png vers val
# Copié: image3808.png vers val
# Copié: image4584.png vers val
# Copié: image4892.png vers val
# Copié: image4264.png vers val
# Copié: image4289.png vers val
# Copié: image4119.png vers val
# Copié: image3684.png vers val
# Copié: image4680.png vers val
# Copié: image3970.png vers val
# Copié: image3844.png vers val
# Copié: image4437.png vers val
# Copié: image3789.png vers val
# Copié: image4453.png vers val
# Copié: image4151.png vers val
# Copié: image3727.png vers val
# Copié: image4563.png vers val
# Copié: image4197.png vers val
# Copié: image3503.png vers val
# Copié: image4702.png vers val
# Copié: image4244.png vers val
# Copié: image4532.png vers val
# Copié: image4870.png vers val
# Copié: image4648.png vers val
# Copié: image4345.png vers val
# Copié: image3850.png vers val
# Copié: image4242.png vers val
# Copié: image3911.png vers val
# Copié: image3554.png vers val
# Copié: image4875.png vers val
# Copié: image4721.png vers val
# Copié: image4444.png vers val
# Copié: image4189.png vers val
# Copié: image3910.png vers val
# Copié: image4081.png vers val
# Copié: image4322.png vers val
# Copié: image4296.png vers val
# Copié: image3635.png vers val
# Copié: image3973.png vers val
# Copié: image3750.png vers val
# Copié: image3690.png vers val
# Copié: image4935.png vers val
# Copié: image4395.png vers val
# Copié: image4177.png vers val
# Copié: image4509.png vers val
# Copié: image4240.png vers val
# Copié: image4623.png vers val
# Copié: image4115.png vers val
# Copié: image4972.png vers val
# Copié: image4258.png vers val
# Copié: image4292.png vers val
# Copié: image4629.png vers val
# Copié: image4291.png vers val
# Copié: image4188.png vers val
# Copié: image4448.png vers val
# Copié: image4418.png vers val
# Copié: image4734.png vers val
# Copié: image4842.png vers val
# Copié: image4504.png vers val
# Copié: image4631.png vers val
# Copié: image3805.png vers val
# Copié: image4575.png vers val
# Copié: image3972.png vers val
# Copié: image4040.png vers val
# Copié: image3659.png vers val
# Copié: image4214.png vers val
# Copié: image4587.png vers val
# Copié: image4270.png vers val
# Copié: image4199.png vers val
# Copié: image4213.png vers val
# Copié: image4474.png vers val
# Copié: image4384.png vers val
# Copié: image4266.png vers val
# Copié: image4641.png vers val
# Copié: image3658.png vers val
# Copié: image4823.png vers val
# Copié: image4496.png vers val
# Copié: image3784.png vers val
# Copié: image4773.png vers val
# Copié: image4331.png vers val
# Copié: image3738.png vers val
# Copié: image4066.png vers val
# Copié: image4281.png vers val
# Copié: image4797.png vers val
# Copié: image4644.png vers val
# Copié: image4982.png vers val
# Copié: image3744.png vers val
# Copié: image3967.png vers val
# Copié: image3748.png vers val
# Copié: image4872.png vers val
# Copié: image3811.png vers val
# Copié: image3634.png vers val
# Copié: image4708.png vers val
# Copié: image3893.png vers val
# Copié: image3485.png vers val
# Copié: image3775.png vers val
# Copié: image4301.png vers val
# Copié: image4457.png vers val
# Copié: image4368.png vers val
# Copié: image4578.png vers val
# Copié: image3858.png vers val
# Copié: image3880.png vers val
# Copié: image3663.png vers val
# Copié: image4257.png vers val
# Copié: image3546.png vers val
# Copié: image3892.png vers val
# Copié: image4819.png vers val
# Copié: image3508.png vers val
# Copié: image4964.png vers val
# Copié: image4480.png vers val
# Copié: image3835.png vers val
# Copié: image3582.png vers val
# Copié: image3904.png vers val
# Copié: image4376.png vers val
# Copié: image4714.png vers val
# Copié: image4633.png vers val
# Copié: image3714.png vers val
# Copié: image4227.png vers val
# Copié: image4953.png vers val
# Copié: image4104.png vers val
# Copié: image3888.png vers val
# Copié: image4987.png vers val
# Copié: image4171.png vers val
# Copié: image4523.png vers val
# Copié: image3902.png vers val
# Copié: image4924.png vers val
# Copié: image3642.png vers val
# Copié: image4646.png vers val
# Copié: image4340.png vers val
# Copié: image3717.png vers val
# Copié: image4576.png vers val
# Copié: image4425.png vers val
# Copié: image4855.png vers val
# Copié: image4670.png vers val
# Copié: image4592.png vers val
# Copié: image4087.png vers val
# Copié: image4175.png vers val
# Copié: image4123.png vers val
# Copié: image4704.png vers val
# Copié: image3735.png vers val
# Copié: image4320.png vers val
# Copié: image4122.png vers val
# Copié: image4399.png vers val
# Copié: image3547.png vers val
# Copié: image4904.png vers val
# Copié: image3496.png vers val
# Copié: image4467.png vers val
# Copié: image4638.png vers val
# Copié: image4250.png vers val
# Copié: image4181.png vers val
# Copié: image4054.png vers val
# Copié: image3981.png vers val
# Copié: image4902.png vers val
# Copié: image4895.png vers val
# Copié: image4094.png vers val
# Copié: image3987.png vers val
# Copié: image3615.png vers val
# Copié: image3832.png vers val
# Copié: image4920.png vers val
# Copié: image3779.png vers val
# Copié: image4069.png vers val
# Copié: image4668.png vers val
# Copié: image4367.png vers val
# Copié: image4882.png vers val
# Copié: image4076.png vers val
# Copié: image4374.png vers val
# Copié: image4971.png vers val
# Copié: image3780.png vers val
# Copié: image4999.png vers val
# Copié: image4965.png vers val
# Copié: image4172.png vers val
# Copié: image4454.png vers val
# Copié: image4088.png vers val
# Copié: image4167.png vers val
# Copié: image4555.png vers val
# Copié: image4643.png vers val
# Copié: image3732.png vers val
# Copié: image3755.png vers val
# Copié: image4179.png vers val
# Copié: image4079.png vers val
# Copié: image4793.png vers val
# Copié: image4269.png vers val
# Copié: image4988.png vers val
# Copié: image3943.png vers val
# Copié: image3996.png vers val
# Copié: image4735.png vers val
# Copié: image3982.png vers val
# Copié: image4751.png vers val
# Copié: image4372.png vers val
# Copié: image4749.png vers val
# Copié: image3622.png vers val
# Copié: image4607.png vers val
# Copié: image4777.png vers val
# Copié: image3976.png vers val
# Copié: image4951.png vers val
# Copié: image4402.png vers val
# Copié: image3623.png vers val
# Copié: image4588.png vers val
# Copié: image4583.png vers val
# Copié: image3574.png vers val
# Copié: image4204.png vers val
# Copié: image3477.png vers val
# Copié: image3553.png vers val
# Copié: image4954.png vers val
# Copié: image4540.png vers val
# Copié: image4899.png vers val
# Copié: image3498.png vers val
# Copié: image4341.png vers val
# Copié: image4685.png vers val
# Copié: image4605.png vers val
# Copié: image4031.png vers val
# Copié: image4290.png vers val
# Copié: image4567.png vers val
# Copié: image4347.png vers val
# Copié: image4249.png vers val
# Copié: image4901.png vers val
# Copié: image4705.png vers val
# Copié: image4590.png vers val
# Copié: image4810.png vers val
# Copié: image3639.png vers val
#
# Nombre final d'images dans train: 4195
# Nombre final de masques dans train: 4195
# Nombre final d'images dans val: 805
# Nombre final de masques dans val: 805

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# Créer les datasets à partir des chemins d'images
train_ds = tf.data.Dataset.from_tensor_slices((train_img, train_label))
val_ds = tf.data.Dataset.from_tensor_slices((val_img, val_label))

# %%
# Fonctions de lecture d'images
def read_png(img):
    img = tf.io.read_file(img)
    img = tf.image.decode_png(img, channels=3)
    return img
    
def read_png_label(img):
    img = tf.io.read_file(img)
    img = tf.image.decode_png(img, channels=1)  
    return img

# %%
# Data Augmentation
def rand_crop(img, label):
    concat_img = tf.concat([img, label], axis=-1)
    concat_img = tf.image.resize(concat_img, [280, 560], method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
    crop_img = tf.image.random_crop(concat_img, [256, 256, 4])
    return crop_img[:, :, :3], crop_img[:, :, 3:]

def norm(img, label):
    img = tf.cast(img, tf.float32)/127.5-1
    label = tf.cast(label, tf.int32)
    return img, label

def load_img_train(img, label):
    img = read_png(img)
    label = read_png_label(label)
    
    img, label = rand_crop(img, label)
    
    if tf.random.uniform(()) > 0.5:
        img = tf.image.flip_left_right(img)
        label = tf.image.flip_left_right(label)
    return norm(img, label)

def load_img_val(img, label):
    img = read_png(img)
    label = read_png_label(label)
    
    img = tf.image.resize(img, [256, 256])
    label = tf.image.resize(label, [256, 256])
    return norm(img, label)

# %%
# Configuration des paramètres
BATCH_SIZE = 32
BUFFER_SIZE = 300
steps_per_epoch = 4195 // BATCH_SIZE  # Adapté à votre nombre d'images de train
validation_steps = 805 // BATCH_SIZE   # Adapté à votre nombre d'images de validation
auto = tf.data.experimental.AUTOTUNE

# Préparation des datasets
train_ds = train_ds.map(load_img_train, num_parallel_calls=auto)
train_ds = train_ds.cache().repeat().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).prefetch(auto)

val_ds = val_ds.map(load_img_val, num_parallel_calls=auto)
val_ds = val_ds.cache().batch(BATCH_SIZE)

# %%
# Visualisation d'un exemple
for img, label in val_ds.take(1):
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.imshow((img[0] + 1)/2)
    plt.title('Image')
    plt.axis('off')
    
    plt.subplot(1, 2, 2)
    plt.imshow(np.squeeze(label[0]), cmap='gray')
    plt.title('Mask')
    plt.axis('off')
    plt.show()

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint

# Définition de la métrique IoU personnalisée
class MeanIoU(tf.keras.metrics.MeanIoU):
    def __call__(self, y_true, y_pred, sample_weight=None):
        y_pred = tf.argmax(y_pred, axis=-1)
        return super().__call__(y_true, y_pred, sample_weight=sample_weight)

def create_model():
    inputs = tf.keras.layers.Input(shape=(256, 256, 3))
    # Encoder Path (Contraction)
    print("Encoder dimensions:")
    # Block 1
    x = tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu')(inputs)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    skip1 = x
    print("Skip1 shape:", skip1.shape)
    x = tf.keras.layers.MaxPooling2D(padding='same')(x)
    # Block 2
    x = tf.keras.layers.Conv2D(128, 3, padding='same', activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(128, 3, padding='same', activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    skip2 = x
    print("Skip2 shape:", skip2.shape)
    x = tf.keras.layers.MaxPooling2D(padding='same')(x)
    # Block 3
    x = tf.keras.layers.Conv2D(256, 3, padding='same', activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(256, 3, padding='same', activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    skip3 = x
    print("Skip3 shape:", skip3.shape)
    x = tf.keras.layers.MaxPooling2D(padding='same')(x)
    # Block 4
    x = tf.keras.layers.Conv2D(512, 3, padding='same', activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(512, 3, padding='same', activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    skip4 = x
    print("Skip4 shape:", skip4.shape)
    x = tf.keras.layers.MaxPooling2D(padding='same')(x)
    
    print("\nBottleneck dimensions:")
    # Bridge
    x = tf.keras.layers.Conv2D(1024, 3, padding='same', activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(1024, 3, padding='same', activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    print("Bridge shape:", x.shape)
    
    print("\nDecoder dimensions:")
    # Decoder Path (Expansion)
    # Block 5
    x = tf.keras.layers.Conv2DTranspose(512, 2, strides=2, padding='same', activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    print("Before concat4 shape:", x.shape)
    print("Skip4 shape:", skip4.shape)
    x = tf.keras.layers.Concatenate()([skip4, x])
    x = tf.keras.layers.Conv2D(512, 3, padding='same', activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(512, 3, padding='same', activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    # Block 6
    x = tf.keras.layers.Conv2DTranspose(256, 2, strides=2, padding='same', activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    print("Before concat3 shape:", x.shape)
    print("Skip3 shape:", skip3.shape)
    x = tf.keras.layers.Concatenate()([skip3, x])
    x = tf.keras.layers.Conv2D(256, 3, padding='same', activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(256, 3, padding='same', activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    # Block 7
    x = tf.keras.layers.Conv2DTranspose(128, 2, strides=2, padding='same', activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    print("Before concat2 shape:", x.shape)
    print("Skip2 shape:", skip2.shape)
    x = tf.keras.layers.Concatenate()([skip2, x])
    x = tf.keras.layers.Conv2D(128, 3, padding='same', activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(128, 3, padding='same', activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    # Block 8
    x = tf.keras.layers.Conv2DTranspose(64, 2, strides=2, padding='same', activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    print("Before concat1 shape:", x.shape)
    print("Skip1 shape:", skip1.shape)
    x = tf.keras.layers.Concatenate()([skip1, x])
    x = tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    # Output Layer
    outputs = tf.keras.layers.Conv2D(34, 1, activation='softmax')(x)
    print("\nOutput shape:", outputs.shape)
    
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# Créer le modèle et voir les dimensions
model = create_model()

# Compilation et rappel des callbacks
model_path = 'myunet1.keras'
callbacks = [
    ModelCheckpoint(
        model_path, 
        monitor="val_loss", 
        verbose=1,
        save_best_only=True,
        mode='min'
    )
]

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['acc', MeanIoU(num_classes=34)]
)

print("\nRésumé du modèle:")
model.summary()
# Out:
# Encoder dimensions:
# Skip1 shape: (None, 256, 256, 64)
# Skip2 shape: (None, 128, 128, 128)
# Skip3 shape: (None, 64, 64, 256)
# Skip4 shape: (None, 32, 32, 512)
#
# Bottleneck dimensions:
# Bridge shape: (None, 16, 16, 1024)
#
# Decoder dimensions:
# Before concat4 shape: (None, 32, 32, 512)
# Skip4 shape: (None, 32, 32, 512)
# Before concat3 shape: (None, 64, 64, 256)
# Skip3 shape: (None, 64, 64, 256)
# Before concat2 shape: (None, 128, 128, 128)
# Skip2 shape: (None, 128, 128, 128)
# Before concat1 shape: (None, 256, 256, 64)
# Skip1 shape: (None, 256, 256, 64)
#
# Output shape: (None, 256, 256, 34)
#
# Résumé du modèle:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 256, 256, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 256, 256, 64)   │          1,792 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 256, 256, 64)   │            256 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 256, 256, 64)   │         36,928 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 256, 256, 64)   │            256 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 128, 128, 64)   │              0 │ batch_normalization_1… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 128, 128, 128)  │         73,856 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 128, 128, 128)  │            512 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 128, 128, 128)  │        147,584 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 128, 128, 128)  │            512 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 64, 64, 128)    │              0 │ batch_normalization_3… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 64, 64, 256)    │        295,168 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 64, 64, 256)    │          1,024 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 64, 64, 256)    │        590,080 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 64, 64, 256)    │          1,024 │ conv2d_5[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 32, 32, 256)    │              0 │ batch_normalization_5… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 32, 32, 512)    │      1,180,160 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 32, 32, 512)    │          2,048 │ conv2d_6[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 32, 32, 512)    │      2,359,808 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 32, 32, 512)    │          2,048 │ conv2d_7[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 16, 16, 512)    │              0 │ batch_normalization_7… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 16, 16, 1024)   │      4,719,616 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 16, 16, 1024)   │          4,096 │ conv2d_8[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 16, 16, 1024)   │      9,438,208 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 16, 16, 1024)   │          4,096 │ conv2d_9[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 32, 32, 512)    │      2,097,664 │ batch_normalization_9… │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 32, 32, 512)    │          2,048 │ conv2d_transpose[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 32, 32, 1024)   │              0 │ batch_normalization_7… │
# │                           │                        │                │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 32, 32, 512)    │      4,719,104 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 32, 32, 512)    │          2,048 │ conv2d_10[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 32, 32, 512)    │      2,359,808 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 32, 32, 512)    │          2,048 │ conv2d_11[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 64, 64, 256)    │        524,544 │ batch_normalization_1… │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 64, 64, 256)    │          1,024 │ conv2d_transpose_1[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 64, 64, 512)    │              0 │ batch_normalization_5… │
# │ (Concatenate)             │                        │                │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 64, 64, 256)    │      1,179,904 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_14    │ (None, 64, 64, 256)    │          1,024 │ conv2d_12[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 64, 64, 256)    │        590,080 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_15    │ (None, 64, 64, 256)    │          1,024 │ conv2d_13[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 128, 128, 128)  │        131,200 │ batch_normalization_1… │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_16    │ (None, 128, 128, 128)  │            512 │ conv2d_transpose_2[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 128, 128, 256)  │              0 │ batch_normalization_3… │
# │ (Concatenate)             │                        │                │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 128, 128, 128)  │        295,040 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_17    │ (None, 128, 128, 128)  │            512 │ conv2d_14[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 128, 128, 128)  │        147,584 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_18    │ (None, 128, 128, 128)  │            512 │ conv2d_15[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_3        │ (None, 256, 256, 64)   │         32,832 │ batch_normalization_1… │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_19    │ (None, 256, 256, 64)   │            256 │ conv2d_transpose_3[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 256, 256, 128)  │              0 │ batch_normalization_1… │
# │ (Concatenate)             │                        │                │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 256, 256, 64)   │         73,792 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_20    │ (None, 256, 256, 64)   │            256 │ conv2d_16[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 256, 256, 64)   │         36,928 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_21    │ (None, 256, 256, 64)   │            256 │ conv2d_17[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 256, 256, 34)   │          2,210 │ batch_normalization_2… │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 31,061,282 (118.49 MB)
#  Trainable params: 31,047,586 (118.44 MB)
#  Non-trainable params: 13,696 (53.50 KB)

# %%
class CustomMeanIoU(tf.keras.metrics.MeanIoU):
    def __init__(self, num_classes, name=None, dtype=None):
        super().__init__(num_classes=num_classes, name=name, dtype=dtype)
    
    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.squeeze(y_true, axis=-1)
        y_pred = tf.argmax(y_pred, axis=-1)
        y_true = tf.cast(y_true, tf.int32)
        y_pred = tf.cast(y_pred, tf.int32)
        return super().update_state(y_true, y_pred, sample_weight)

class MulticlassF1Score(tf.keras.metrics.F1Score):
    def __init__(self, average='macro', name=None, dtype=None):
        super().__init__(average=average, name=name, dtype=dtype)
    
    def update_state(self, y_true, y_pred, sample_weight=None):
        # Aplatir les dimensions spatiales
        y_true = tf.reshape(tf.squeeze(y_true, axis=-1), [-1])
        y_true = tf.one_hot(tf.cast(y_true, tf.int32), depth=34)
        
        # Reshape y_pred pour correspondre au format attendu
        y_pred = tf.reshape(y_pred, [-1, 34])
        
        return super().update_state(y_true, y_pred, sample_weight)

class MulticlassRecall(tf.keras.metrics.Recall):
    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.reshape(tf.squeeze(y_true, axis=-1), [-1])
        y_pred = tf.reshape(tf.argmax(y_pred, axis=-1), [-1])
        return super().update_state(y_true, y_pred, sample_weight)

class MulticlassPrecision(tf.keras.metrics.Precision):
    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.reshape(tf.squeeze(y_true, axis=-1), [-1])
        y_pred = tf.reshape(tf.argmax(y_pred, axis=-1), [-1])
        return super().update_state(y_true, y_pred, sample_weight)

# %%
# Compilation du modèle
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=[
        'accuracy',
        CustomMeanIoU(num_classes=34),
        MulticlassRecall(name='recall'),
        MulticlassPrecision(name='precision'),
        MulticlassF1Score(name='f1_score')
    ]
)

# Configuration des callbacks sans EarlyStopping
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        'myunet1.keras',
        monitor='val_loss',
        save_best_only=True,
        mode='min',
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.2,
        patience=3,
        min_lr=1e-6
    ),
    tf.keras.callbacks.CSVLogger('training_log.csv')
]

# Entraînement
history = model.fit(
    train_ds,
    validation_data=val_ds,
    steps_per_epoch=steps_per_epoch,
    validation_steps=validation_steps,
    epochs=50,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6268 - custom_mean_io_u: 0.0718 - f1_score: 0.1077 - loss: 1.5844 - precision: 0.9999 - recall: 0.9977
# Epoch 1: val_loss improved from inf to 7.90927, saving model to myunet1.keras
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 330s 2s/step - accuracy: 0.6274 - custom_mean_io_u: 0.0719 - f1_score: 0.1079 - loss: 1.5812 - precision: 0.9999 - recall: 0.9977 - val_accuracy: 0.3314 - val_custom_mean_io_u: 0.0105 - val_f1_score: 0.0161 - val_loss: 7.9093 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 2/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 755ms/step - accuracy: 0.7848 - custom_mean_io_u: 0.1299 - f1_score: 0.1707 - loss: 0.7921 - precision: 0.9999 - recall: 1.0000
# Epoch 2: val_loss improved from 7.90927 to 2.33693, saving model to myunet1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 105s 803ms/step - accuracy: 0.7849 - custom_mean_io_u: 0.1298 - f1_score: 0.1708 - loss: 0.7918 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.4316 - val_custom_mean_io_u: 0.0374 - val_f1_score: 0.0551 - val_loss: 2.3369 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 3/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.8143 - custom_mean_io_u: 0.1515 - f1_score: 0.1951 - loss: 0.6716 - precision: 0.9999 - recall: 1.0000
# Epoch 3: val_loss did not improve from 2.33693
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.8143 - custom_mean_io_u: 0.1515 - f1_score: 0.1952 - loss: 0.6715 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.4040 - val_custom_mean_io_u: 0.0496 - val_f1_score: 0.0769 - val_loss: 2.3639 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 4/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.8329 - custom_mean_io_u: 0.1727 - f1_score: 0.2219 - loss: 0.6023 - precision: 0.9999 - recall: 1.0000
# Epoch 4: val_loss improved from 2.33693 to 1.35468, saving model to myunet1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 105s 803ms/step - accuracy: 0.8330 - custom_mean_io_u: 0.1727 - f1_score: 0.2219 - loss: 0.6023 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.6507 - val_custom_mean_io_u: 0.1187 - val_f1_score: 0.1616 - val_loss: 1.3547 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 5/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.8448 - custom_mean_io_u: 0.1908 - f1_score: 0.2421 - loss: 0.5577 - precision: 0.9998 - recall: 1.0000
# Epoch 5: val_loss improved from 1.35468 to 0.97074, saving model to myunet1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 105s 803ms/step - accuracy: 0.8448 - custom_mean_io_u: 0.1907 - f1_score: 0.2422 - loss: 0.5576 - precision: 0.9998 - recall: 1.0000 - val_accuracy: 0.7510 - val_custom_mean_io_u: 0.1596 - val_f1_score: 0.2070 - val_loss: 0.9707 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 6/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.8505 - custom_mean_io_u: 0.2054 - f1_score: 0.2644 - loss: 0.5304 - precision: 0.9999 - recall: 1.0000
# Epoch 6: val_loss did not improve from 0.97074
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.8506 - custom_mean_io_u: 0.2053 - f1_score: 0.2645 - loss: 0.5303 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.7332 - val_custom_mean_io_u: 0.1690 - val_f1_score: 0.2253 - val_loss: 1.0603 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 7/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.8568 - custom_mean_io_u: 0.2177 - f1_score: 0.2793 - loss: 0.5055 - precision: 0.9999 - recall: 1.0000
# Epoch 7: val_loss improved from 0.97074 to 0.85125, saving model to myunet1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 105s 803ms/step - accuracy: 0.8568 - custom_mean_io_u: 0.2177 - f1_score: 0.2793 - loss: 0.5054 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.7763 - val_custom_mean_io_u: 0.1899 - val_f1_score: 0.2449 - val_loss: 0.8512 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 8/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.8657 - custom_mean_io_u: 0.2329 - f1_score: 0.2992 - loss: 0.4726 - precision: 0.9999 - recall: 1.0000
# Epoch 8: val_loss did not improve from 0.85125
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.8657 - custom_mean_io_u: 0.2329 - f1_score: 0.2992 - loss: 0.4725 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.7849 - val_custom_mean_io_u: 0.1996 - val_f1_score: 0.2550 - val_loss: 0.8526 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 9/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.8693 - custom_mean_io_u: 0.2481 - f1_score: 0.3197 - loss: 0.4527 - precision: 0.9999 - recall: 1.0000
# Epoch 9: val_loss did not improve from 0.85125
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.8693 - custom_mean_io_u: 0.2480 - f1_score: 0.3197 - loss: 0.4527 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.7721 - val_custom_mean_io_u: 0.2036 - val_f1_score: 0.2628 - val_loss: 0.9114 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 10/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 755ms/step - accuracy: 0.8694 - custom_mean_io_u: 0.2498 - f1_score: 0.3220 - loss: 0.4471 - precision: 0.9999 - recall: 1.0000
# Epoch 10: val_loss did not improve from 0.85125
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.8695 - custom_mean_io_u: 0.2498 - f1_score: 0.3221 - loss: 0.4470 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.7793 - val_custom_mean_io_u: 0.2046 - val_f1_score: 0.2620 - val_loss: 0.8645 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 11/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 755ms/step - accuracy: 0.8840 - custom_mean_io_u: 0.2875 - f1_score: 0.3680 - loss: 0.3882 - precision: 0.9999 - recall: 1.0000
# Epoch 11: val_loss improved from 0.85125 to 0.74318, saving model to myunet1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 105s 804ms/step - accuracy: 0.8840 - custom_mean_io_u: 0.2875 - f1_score: 0.3681 - loss: 0.3881 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8048 - val_custom_mean_io_u: 0.2322 - val_f1_score: 0.2975 - val_loss: 0.7432 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 2.0000e-04
# Epoch 12/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 755ms/step - accuracy: 0.8925 - custom_mean_io_u: 0.3111 - f1_score: 0.4000 - loss: 0.3589 - precision: 0.9999 - recall: 1.0000
# Epoch 12: val_loss improved from 0.74318 to 0.72055, saving model to myunet1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 105s 804ms/step - accuracy: 0.8925 - custom_mean_io_u: 0.3110 - f1_score: 0.4000 - loss: 0.3588 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8116 - val_custom_mean_io_u: 0.2432 - val_f1_score: 0.3103 - val_loss: 0.7205 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 2.0000e-04
# Epoch 13/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 755ms/step - accuracy: 0.8969 - custom_mean_io_u: 0.3264 - f1_score: 0.4190 - loss: 0.3413 - precision: 0.9999 - recall: 1.0000
# Epoch 13: val_loss improved from 0.72055 to 0.70160, saving model to myunet1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 105s 803ms/step - accuracy: 0.8969 - custom_mean_io_u: 0.3264 - f1_score: 0.4191 - loss: 0.3413 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8215 - val_custom_mean_io_u: 0.2448 - val_f1_score: 0.3126 - val_loss: 0.7016 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 2.0000e-04
# Epoch 14/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 755ms/step - accuracy: 0.8984 - custom_mean_io_u: 0.3409 - f1_score: 0.4381 - loss: 0.3357 - precision: 0.9999 - recall: 1.0000
# Epoch 14: val_loss improved from 0.70160 to 0.69581, saving model to myunet1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 105s 804ms/step - accuracy: 0.8984 - custom_mean_io_u: 0.3408 - f1_score: 0.4381 - loss: 0.3356 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8215 - val_custom_mean_io_u: 0.2508 - val_f1_score: 0.3211 - val_loss: 0.6958 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 2.0000e-04
# Epoch 15/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 755ms/step - accuracy: 0.9018 - custom_mean_io_u: 0.3537 - f1_score: 0.4517 - loss: 0.3240 - precision: 0.9999 - recall: 1.0000
# Epoch 15: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 785ms/step - accuracy: 0.9018 - custom_mean_io_u: 0.3537 - f1_score: 0.4518 - loss: 0.3240 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8212 - val_custom_mean_io_u: 0.2506 - val_f1_score: 0.3205 - val_loss: 0.7110 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 2.0000e-04
# Epoch 16/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 755ms/step - accuracy: 0.9040 - custom_mean_io_u: 0.3653 - f1_score: 0.4648 - loss: 0.3153 - precision: 0.9999 - recall: 1.0000
# Epoch 16: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 785ms/step - accuracy: 0.9040 - custom_mean_io_u: 0.3652 - f1_score: 0.4648 - loss: 0.3152 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.7923 - val_custom_mean_io_u: 0.2378 - val_f1_score: 0.3064 - val_loss: 0.8279 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 2.0000e-04
# Epoch 17/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 755ms/step - accuracy: 0.9068 - custom_mean_io_u: 0.3668 - f1_score: 0.4675 - loss: 0.3049 - precision: 0.9999 - recall: 1.0000
# Epoch 17: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.9068 - custom_mean_io_u: 0.3668 - f1_score: 0.4676 - loss: 0.3048 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8040 - val_custom_mean_io_u: 0.2417 - val_f1_score: 0.3110 - val_loss: 0.8002 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 2.0000e-04
# Epoch 18/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 755ms/step - accuracy: 0.9127 - custom_mean_io_u: 0.3922 - f1_score: 0.4914 - loss: 0.2852 - precision: 0.9999 - recall: 1.0000
# Epoch 18: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.9127 - custom_mean_io_u: 0.3922 - f1_score: 0.4915 - loss: 0.2852 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8230 - val_custom_mean_io_u: 0.2608 - val_f1_score: 0.3350 - val_loss: 0.7154 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 4.0000e-05
# Epoch 19/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.9142 - custom_mean_io_u: 0.4057 - f1_score: 0.5088 - loss: 0.2797 - precision: 0.9998 - recall: 1.0000
# Epoch 19: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.9142 - custom_mean_io_u: 0.4056 - f1_score: 0.5088 - loss: 0.2797 - precision: 0.9998 - recall: 1.0000 - val_accuracy: 0.8222 - val_custom_mean_io_u: 0.2588 - val_f1_score: 0.3323 - val_loss: 0.7271 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 4.0000e-05
# Epoch 20/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 755ms/step - accuracy: 0.9175 - custom_mean_io_u: 0.4212 - f1_score: 0.5246 - loss: 0.2700 - precision: 0.9999 - recall: 1.0000
# Epoch 20: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 785ms/step - accuracy: 0.9175 - custom_mean_io_u: 0.4211 - f1_score: 0.5246 - loss: 0.2700 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8218 - val_custom_mean_io_u: 0.2604 - val_f1_score: 0.3348 - val_loss: 0.7352 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 4.0000e-05
# Epoch 21/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.9175 - custom_mean_io_u: 0.4207 - f1_score: 0.5246 - loss: 0.2686 - precision: 0.9999 - recall: 1.0000
# Epoch 21: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.9175 - custom_mean_io_u: 0.4207 - f1_score: 0.5246 - loss: 0.2686 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8228 - val_custom_mean_io_u: 0.2614 - val_f1_score: 0.3364 - val_loss: 0.7330 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 8.0000e-06
# Epoch 22/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.9180 - custom_mean_io_u: 0.4227 - f1_score: 0.5266 - loss: 0.2666 - precision: 0.9998 - recall: 1.0000
# Epoch 22: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.9180 - custom_mean_io_u: 0.4227 - f1_score: 0.5267 - loss: 0.2666 - precision: 0.9998 - recall: 1.0000 - val_accuracy: 0.8223 - val_custom_mean_io_u: 0.2610 - val_f1_score: 0.3358 - val_loss: 0.7364 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 8.0000e-06
# Epoch 23/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.9191 - custom_mean_io_u: 0.4313 - f1_score: 0.5335 - loss: 0.2633 - precision: 0.9999 - recall: 1.0000
# Epoch 23: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.9191 - custom_mean_io_u: 0.4313 - f1_score: 0.5335 - loss: 0.2633 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8227 - val_custom_mean_io_u: 0.2610 - val_f1_score: 0.3358 - val_loss: 0.7361 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 8.0000e-06
# Epoch 24/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.9185 - custom_mean_io_u: 0.4283 - f1_score: 0.5334 - loss: 0.2643 - precision: 0.9999 - recall: 1.0000
# Epoch 24: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.9185 - custom_mean_io_u: 0.4283 - f1_score: 0.5334 - loss: 0.2643 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8226 - val_custom_mean_io_u: 0.2612 - val_f1_score: 0.3361 - val_loss: 0.7376 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 1.6000e-06
# Epoch 25/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.9201 - custom_mean_io_u: 0.4270 - f1_score: 0.5312 - loss: 0.2613 - precision: 0.9999 - recall: 1.0000
# Epoch 25: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.9201 - custom_mean_io_u: 0.4270 - f1_score: 0.5312 - loss: 0.2614 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8224 - val_custom_mean_io_u: 0.2613 - val_f1_score: 0.3363 - val_loss: 0.7384 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 1.6000e-06
# Epoch 26/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.9197 - custom_mean_io_u: 0.4286 - f1_score: 0.5330 - loss: 0.2614 - precision: 0.9999 - recall: 1.0000
# Epoch 26: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.9197 - custom_mean_io_u: 0.4285 - f1_score: 0.5330 - loss: 0.2614 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8226 - val_custom_mean_io_u: 0.2615 - val_f1_score: 0.3365 - val_loss: 0.7382 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 1.6000e-06
# Epoch 27/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.9196 - custom_mean_io_u: 0.4331 - f1_score: 0.5369 - loss: 0.2620 - precision: 0.9999 - recall: 1.0000
# Epoch 27: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.9196 - custom_mean_io_u: 0.4330 - f1_score: 0.5369 - loss: 0.2620 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8225 - val_custom_mean_io_u: 0.2616 - val_f1_score: 0.3367 - val_loss: 0.7377 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 28/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 755ms/step - accuracy: 0.9191 - custom_mean_io_u: 0.4299 - f1_score: 0.5341 - loss: 0.2635 - precision: 0.9999 - recall: 1.0000
# Epoch 28: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.9191 - custom_mean_io_u: 0.4299 - f1_score: 0.5341 - loss: 0.2635 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8227 - val_custom_mean_io_u: 0.2618 - val_f1_score: 0.3370 - val_loss: 0.7373 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 29/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.9183 - custom_mean_io_u: 0.4293 - f1_score: 0.5347 - loss: 0.2652 - precision: 0.9999 - recall: 1.0000
# Epoch 29: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.9183 - custom_mean_io_u: 0.4292 - f1_score: 0.5347 - loss: 0.2652 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8227 - val_custom_mean_io_u: 0.2617 - val_f1_score: 0.3368 - val_loss: 0.7377 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 30/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.9208 - custom_mean_io_u: 0.4360 - f1_score: 0.5379 - loss: 0.2587 - precision: 0.9999 - recall: 1.0000
# Epoch 30: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.9208 - custom_mean_io_u: 0.4359 - f1_score: 0.5379 - loss: 0.2587 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8228 - val_custom_mean_io_u: 0.2616 - val_f1_score: 0.3367 - val_loss: 0.7381 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 31/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.9199 - custom_mean_io_u: 0.4284 - f1_score: 0.5331 - loss: 0.2610 - precision: 0.9999 - recall: 1.0000
# Epoch 31: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.9199 - custom_mean_io_u: 0.4284 - f1_score: 0.5332 - loss: 0.2610 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8226 - val_custom_mean_io_u: 0.2617 - val_f1_score: 0.3369 - val_loss: 0.7379 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 32/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.9208 - custom_mean_io_u: 0.4343 - f1_score: 0.5370 - loss: 0.2580 - precision: 0.9999 - recall: 1.0000
# Epoch 32: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.9208 - custom_mean_io_u: 0.4342 - f1_score: 0.5371 - loss: 0.2580 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8226 - val_custom_mean_io_u: 0.2618 - val_f1_score: 0.3370 - val_loss: 0.7381 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 33/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 755ms/step - accuracy: 0.9194 - custom_mean_io_u: 0.4347 - f1_score: 0.5396 - loss: 0.2620 - precision: 0.9999 - recall: 1.0000
# Epoch 33: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 785ms/step - accuracy: 0.9194 - custom_mean_io_u: 0.4347 - f1_score: 0.5396 - loss: 0.2620 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8228 - val_custom_mean_io_u: 0.2618 - val_f1_score: 0.3370 - val_loss: 0.7382 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 34/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 756ms/step - accuracy: 0.9205 - custom_mean_io_u: 0.4180 - f1_score: 0.5201 - loss: 0.2593 - precision: 0.9998 - recall: 1.0000
# Epoch 34: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 785ms/step - accuracy: 0.9205 - custom_mean_io_u: 0.4180 - f1_score: 0.5202 - loss: 0.2594 - precision: 0.9998 - recall: 1.0000 - val_accuracy: 0.8225 - val_custom_mean_io_u: 0.2617 - val_f1_score: 0.3369 - val_loss: 0.7386 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 35/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 755ms/step - accuracy: 0.9207 - custom_mean_io_u: 0.4390 - f1_score: 0.5434 - loss: 0.2595 - precision: 0.9999 - recall: 1.0000
# Epoch 35: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 785ms/step - accuracy: 0.9207 - custom_mean_io_u: 0.4390 - f1_score: 0.5434 - loss: 0.2595 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8225 - val_custom_mean_io_u: 0.2616 - val_f1_score: 0.3368 - val_loss: 0.7390 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 36/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 755ms/step - accuracy: 0.9199 - custom_mean_io_u: 0.4316 - f1_score: 0.5355 - loss: 0.2609 - precision: 0.9999 - recall: 1.0000
# Epoch 36: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 785ms/step - accuracy: 0.9199 - custom_mean_io_u: 0.4316 - f1_score: 0.5355 - loss: 0.2609 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8224 - val_custom_mean_io_u: 0.2616 - val_f1_score: 0.3368 - val_loss: 0.7391 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 37/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 756ms/step - accuracy: 0.9196 - custom_mean_io_u: 0.4294 - f1_score: 0.5340 - loss: 0.2622 - precision: 0.9999 - recall: 1.0000
# Epoch 37: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 785ms/step - accuracy: 0.9196 - custom_mean_io_u: 0.4294 - f1_score: 0.5341 - loss: 0.2622 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8224 - val_custom_mean_io_u: 0.2618 - val_f1_score: 0.3371 - val_loss: 0.7392 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 38/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 756ms/step - accuracy: 0.9194 - custom_mean_io_u: 0.4343 - f1_score: 0.5372 - loss: 0.2618 - precision: 0.9999 - recall: 1.0000
# Epoch 38: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 785ms/step - accuracy: 0.9194 - custom_mean_io_u: 0.4342 - f1_score: 0.5372 - loss: 0.2618 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8225 - val_custom_mean_io_u: 0.2616 - val_f1_score: 0.3369 - val_loss: 0.7395 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 39/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 755ms/step - accuracy: 0.9197 - custom_mean_io_u: 0.4299 - f1_score: 0.5346 - loss: 0.2611 - precision: 0.9999 - recall: 1.0000
# Epoch 39: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 785ms/step - accuracy: 0.9197 - custom_mean_io_u: 0.4299 - f1_score: 0.5347 - loss: 0.2611 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8224 - val_custom_mean_io_u: 0.2617 - val_f1_score: 0.3370 - val_loss: 0.7389 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 40/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 755ms/step - accuracy: 0.9207 - custom_mean_io_u: 0.4315 - f1_score: 0.5359 - loss: 0.2588 - precision: 0.9999 - recall: 1.0000
# Epoch 40: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 785ms/step - accuracy: 0.9207 - custom_mean_io_u: 0.4314 - f1_score: 0.5359 - loss: 0.2588 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8225 - val_custom_mean_io_u: 0.2616 - val_f1_score: 0.3369 - val_loss: 0.7396 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 41/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.9190 - custom_mean_io_u: 0.4343 - f1_score: 0.5397 - loss: 0.2638 - precision: 0.9999 - recall: 1.0000
# Epoch 41: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.9190 - custom_mean_io_u: 0.4342 - f1_score: 0.5397 - loss: 0.2638 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8226 - val_custom_mean_io_u: 0.2618 - val_f1_score: 0.3370 - val_loss: 0.7389 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 42/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 755ms/step - accuracy: 0.9202 - custom_mean_io_u: 0.4321 - f1_score: 0.5351 - loss: 0.2603 - precision: 0.9999 - recall: 1.0000
# Epoch 42: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 785ms/step - accuracy: 0.9202 - custom_mean_io_u: 0.4320 - f1_score: 0.5351 - loss: 0.2603 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8224 - val_custom_mean_io_u: 0.2616 - val_f1_score: 0.3368 - val_loss: 0.7403 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 43/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 755ms/step - accuracy: 0.9187 - custom_mean_io_u: 0.4352 - f1_score: 0.5400 - loss: 0.2641 - precision: 0.9998 - recall: 1.0000
# Epoch 43: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.9187 - custom_mean_io_u: 0.4351 - f1_score: 0.5400 - loss: 0.2641 - precision: 0.9998 - recall: 1.0000 - val_accuracy: 0.8226 - val_custom_mean_io_u: 0.2617 - val_f1_score: 0.3370 - val_loss: 0.7398 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 44/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 755ms/step - accuracy: 0.9182 - custom_mean_io_u: 0.4274 - f1_score: 0.5328 - loss: 0.2653 - precision: 0.9998 - recall: 1.0000
# Epoch 44: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.9183 - custom_mean_io_u: 0.4273 - f1_score: 0.5329 - loss: 0.2653 - precision: 0.9998 - recall: 1.0000 - val_accuracy: 0.8225 - val_custom_mean_io_u: 0.2618 - val_f1_score: 0.3370 - val_loss: 0.7400 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 45/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 755ms/step - accuracy: 0.9198 - custom_mean_io_u: 0.4358 - f1_score: 0.5402 - loss: 0.2617 - precision: 0.9999 - recall: 1.0000
# Epoch 45: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.9198 - custom_mean_io_u: 0.4358 - f1_score: 0.5403 - loss: 0.2617 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8226 - val_custom_mean_io_u: 0.2618 - val_f1_score: 0.3371 - val_loss: 0.7400 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 46/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 755ms/step - accuracy: 0.9197 - custom_mean_io_u: 0.4374 - f1_score: 0.5436 - loss: 0.2608 - precision: 0.9999 - recall: 1.0000
# Epoch 46: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.9197 - custom_mean_io_u: 0.4373 - f1_score: 0.5436 - loss: 0.2608 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8225 - val_custom_mean_io_u: 0.2616 - val_f1_score: 0.3369 - val_loss: 0.7404 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 47/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.9209 - custom_mean_io_u: 0.4380 - f1_score: 0.5409 - loss: 0.2585 - precision: 0.9999 - recall: 1.0000
# Epoch 47: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.9209 - custom_mean_io_u: 0.4379 - f1_score: 0.5409 - loss: 0.2585 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8224 - val_custom_mean_io_u: 0.2617 - val_f1_score: 0.3369 - val_loss: 0.7406 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 48/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 755ms/step - accuracy: 0.9201 - custom_mean_io_u: 0.4353 - f1_score: 0.5388 - loss: 0.2602 - precision: 0.9999 - recall: 1.0000
# Epoch 48: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.9201 - custom_mean_io_u: 0.4353 - f1_score: 0.5389 - loss: 0.2602 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8226 - val_custom_mean_io_u: 0.2619 - val_f1_score: 0.3372 - val_loss: 0.7405 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 49/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.9194 - custom_mean_io_u: 0.4357 - f1_score: 0.5397 - loss: 0.2618 - precision: 0.9999 - recall: 1.0000
# Epoch 49: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 784ms/step - accuracy: 0.9194 - custom_mean_io_u: 0.4357 - f1_score: 0.5398 - loss: 0.2618 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8224 - val_custom_mean_io_u: 0.2619 - val_f1_score: 0.3372 - val_loss: 0.7407 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 1.0000e-06
# Epoch 50/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 755ms/step - accuracy: 0.9198 - custom_mean_io_u: 0.4355 - f1_score: 0.5404 - loss: 0.2611 - precision: 0.9999 - recall: 1.0000
# Epoch 50: val_loss did not improve from 0.69581
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 103s 785ms/step - accuracy: 0.9198 - custom_mean_io_u: 0.4354 - f1_score: 0.5404 - loss: 0.2611 - precision: 0.9999 - recall: 1.0000 - val_accuracy: 0.8223 - val_custom_mean_io_u: 0.2615 - val_f1_score: 0.3367 - val_loss: 0.7420 - val_precision: 0.9997 - val_recall: 1.0000 - learning_rate: 1.0000e-06

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set the seaborn style to white for a plain background
sns.set_style("white")
plt.style.use("seaborn")

# Read the CSV file
history_df = pd.read_csv('training_log.csv')

# Create a figure and axis
fig, ax = plt.subplots(figsize=(12, 6))

# Plot Training Mean IoU
ax.plot(history_df['epoch'], history_df['custom_mean_io_u'], label='Training Mean IoU', linewidth=2)

# Plot Validation Mean IoU in red
ax.plot(history_df['epoch'], history_df['val_custom_mean_io_u'], label='Validation Mean IoU', linewidth=2, color='red')

# Set titles and labels
ax.set_title('Mean IoU au cours de l\'entraînement', fontsize=14, pad=15)
ax.set_xlabel('Époque')
ax.set_ylabel('Mean IoU')

# Add legend
ax.legend(loc='best')

# Display the plot
plt.show()
# Out:
# <ipython-input-15-a3e930b467bc>:7: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set the seaborn style for better visuals
sns.set_style("whitegrid")
plt.style.use("seaborn")

# Read the CSV file
history_df = pd.read_csv('training_log.csv')

# Create a figure and axis
fig, ax = plt.subplots(figsize=(12, 6))

# Plot Training and Validation Accuracy
ax.plot(history_df['epoch'], history_df['accuracy'], label='Training Accuracy', linewidth=2)
ax.plot(history_df['epoch'], history_df['val_accuracy'], label='Validation Accuracy', linewidth=2, color='red')

# Set titles and labels
ax.set_title('Accuracy au cours de l\'entraînement', fontsize=14, pad=15)
ax.set_xlabel('Époque')
ax.set_ylabel('Accuracy')

# Add legend and grid
ax.legend(loc='best')
ax.grid(True)

# Display the plot
plt.show()
# Out:
# <ipython-input-16-20124c7ad702>:7: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
num = 3

# Obtenir des prédictions pour un batch d'entraînement
for images, labels in train_ds.take(1):
   predictions = model.predict(images)
   pred_masks = tf.argmax(predictions, axis=-1)
   pred_masks = pred_masks[..., tf.newaxis]
   
   # Créer une figure avec 3 lignes (images) et 3 colonnes (original, vérité terrain, prédiction)
   plt.figure(figsize=(15, 15))
   
   titles = ['Image', 'Vérité terrain', 'Prédiction']
   
   for i in range(num):
       # Image originale
       plt.subplot(num, 3, i*3 + 1)
       # Denormaliser l'image
       display_img = (images[i] + 1) / 2
       plt.imshow(display_img)
       plt.title(titles[0] if i == 0 else '')
       plt.axis('off')
       
       # Masque réel
       plt.subplot(num, 3, i*3 + 2)
       plt.imshow(tf.squeeze(labels[i]), cmap='tab20')
       plt.title(titles[1] if i == 0 else '')
       plt.axis('off')
       
       # Masque prédit
       plt.subplot(num, 3, i*3 + 3)
       plt.imshow(tf.squeeze(pred_masks[i]), cmap='tab20')
       plt.title(titles[2] if i == 0 else '')
       plt.axis('off')
   
   plt.suptitle('Comparaison des segmentations (Ensemble d\'entraînement)', fontsize=16, y=0.95)
   plt.tight_layout()
   plt.show()

# Afficher quelques statistiques
print("Statistiques des prédictions sur l'ensemble d'entraînement:")
print(f"Valeurs uniques dans les prédictions: {tf.unique(tf.reshape(pred_masks, [-1]))[0].numpy()}")
print(f"Nombre de classes prédites: {len(tf.unique(tf.reshape(pred_masks, [-1]))[0])}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Statistiques des prédictions sur l'ensemble d'entraînement:
# Valeurs uniques dans les prédictions: [11 23 21 17 20 26  4 13 24 22 12  7  8  6  1 19 33 32  9  2  5 27 28 31
#  25 15 10  3]
# Nombre de classes prédites: 28
